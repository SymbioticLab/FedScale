# %% [markdown]
# # Federated Learning for Image Classification on IID CIFAR10 using Fedscale

# %% [markdown]
# ## Client Side

# %%
import torch
import logging
import math
from torch.autograd import Variable
import numpy as np

import sys, os
sys.path.insert(1, os.path.join(sys.path[0], './FedScale/core'))
from FedScale.core.client import Client
from FedScale.core.executor import Executor
from FedScale.core.fl_client_libs import args

Demo_Executor = Executor(args)

# %%
Demo_Executor.run()
# Out:
# (03-04) 18:59:15 INFO     [executor.py:50] (EXECUTOR:1) is setting up environ ...
# (03-04) 18:59:15 INFO     [fllibs.py:84] Initializing the model ...
# Files already downloaded and verified
# Files already downloaded and verified
# (03-04) 18:59:16 INFO     [executor.py:119] Data partitioner starts ...
# (03-04) 18:59:16 INFO     [divide_data.py:94] Randomly partitioning data, 50000 samples...
# (03-04) 18:59:16 INFO     [divide_data.py:94] Randomly partitioning data, 10000 samples...
# (03-04) 18:59:16 INFO     [executor.py:127] Data partitioner completes ...
# (03-04) 18:59:16 INFO     [executor.py:87] Connecting to Coordinator (127.0.0.1) for control plane communication ...
# (03-04) 18:59:16 INFO     [executor.py:100] Started GRPC server at [::]:10002 for control plane
# (03-04) 18:59:16 INFO     [executor.py:302] Start monitoring events ...
# (03-04) 18:59:29 INFO     [executor.py:196] Received GRPC ReportExecutorInfo request
# (03-04) 18:59:30 INFO     [executor.py:149] Received GRPC UpdateModel request
# (03-04) 18:59:30 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 18:59:30 INFO     [client.py:17] Start to train (CLIENT: 1) ...
# (03-04) 18:59:32 INFO     [client.py:187] Training of (CLIENT: 1) completes, {'clientId': 1, 'moving_loss': 6.166736531928269, 'trained_size': 600, 'success': True, 'utility': 14002.723716596103}
# (03-04) 18:59:32 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 18:59:33 INFO     [client.py:17] Start to train (CLIENT: 2) ...
# (03-04) 18:59:35 INFO     [client.py:187] Training of (CLIENT: 2) completes, {'clientId': 2, 'moving_loss': 8.450328796211208, 'trained_size': 600, 'success': True, 'utility': 27784.575430198744}
# (03-04) 18:59:35 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 18:59:35 INFO     [client.py:17] Start to train (CLIENT: 3) ...
# (03-04) 18:59:38 INFO     [client.py:187] Training of (CLIENT: 3) completes, {'clientId': 3, 'moving_loss': 5.541807488564527, 'trained_size': 600, 'success': True, 'utility': 2746.5351530115886}
# (03-04) 18:59:38 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 18:59:38 INFO     [client.py:17] Start to train (CLIENT: 4) ...
# (03-04) 18:59:42 INFO     [client.py:187] Training of (CLIENT: 4) completes, {'clientId': 4, 'moving_loss': 5.133763529590654, 'trained_size': 600, 'success': True, 'utility': 2885.5709383391113}
# (03-04) 18:59:42 INFO     [executor.py:149] Received GRPC UpdateModel request
# (03-04) 18:59:42 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 18:59:42 INFO     [client.py:17] Start to train (CLIENT: 1) ...
# (03-04) 18:59:46 INFO     [client.py:187] Training of (CLIENT: 1) completes, {'clientId': 1, 'moving_loss': 4.097920617766082, 'trained_size': 600, 'success': True, 'utility': 1503.5819372413082}
# (03-04) 18:59:46 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 18:59:46 INFO     [client.py:17] Start to train (CLIENT: 2) ...
# (03-04) 18:59:50 INFO     [client.py:187] Training of (CLIENT: 2) completes, {'clientId': 2, 'moving_loss': 5.534401371750412, 'trained_size': 600, 'success': True, 'utility': 11159.077982035868}
# (03-04) 18:59:50 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 18:59:50 INFO     [client.py:17] Start to train (CLIENT: 3) ...
# (03-04) 18:59:54 INFO     [client.py:187] Training of (CLIENT: 3) completes, {'clientId': 3, 'moving_loss': 5.330126642058009, 'trained_size': 600, 'success': True, 'utility': 6170.8408601980755}
# (03-04) 18:59:54 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 18:59:54 INFO     [client.py:17] Start to train (CLIENT: 4) ...
# (03-04) 18:59:58 INFO     [client.py:187] Training of (CLIENT: 4) completes, {'clientId': 4, 'moving_loss': 7.039049797966295, 'trained_size': 600, 'success': True, 'utility': 29348.86824140578}
# (03-04) 18:59:58 INFO     [executor.py:149] Received GRPC UpdateModel request
# (03-04) 18:59:58 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 18:59:58 INFO     [client.py:17] Start to train (CLIENT: 1) ...
# (03-04) 19:00:02 INFO     [client.py:187] Training of (CLIENT: 1) completes, {'clientId': 1, 'moving_loss': 5.081957636442971, 'trained_size': 600, 'success': True, 'utility': 1992.5550867611482}
# (03-04) 19:00:02 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:00:02 INFO     [client.py:17] Start to train (CLIENT: 2) ...
# (03-04) 19:00:06 INFO     [client.py:187] Training of (CLIENT: 2) completes, {'clientId': 2, 'moving_loss': 6.0582187644090615, 'trained_size': 600, 'success': True, 'utility': 4488.897376691365}
# (03-04) 19:00:06 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:00:06 INFO     [client.py:17] Start to train (CLIENT: 3) ...
# (03-04) 19:00:10 INFO     [client.py:187] Training of (CLIENT: 3) completes, {'clientId': 3, 'moving_loss': 7.132398456906873, 'trained_size': 600, 'success': True, 'utility': 3649.875449565315}
# (03-04) 19:00:10 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:00:10 INFO     [client.py:17] Start to train (CLIENT: 4) ...
# (03-04) 19:00:14 INFO     [client.py:187] Training of (CLIENT: 4) completes, {'clientId': 4, 'moving_loss': 4.333043703100524, 'trained_size': 600, 'success': True, 'utility': 2171.3751901872533}
# (03-04) 19:00:15 INFO     [executor.py:149] Received GRPC UpdateModel request
# (03-04) 19:00:15 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:00:15 INFO     [client.py:17] Start to train (CLIENT: 1) ...
# (03-04) 19:00:18 INFO     [client.py:187] Training of (CLIENT: 1) completes, {'clientId': 1, 'moving_loss': 4.7663854069129075, 'trained_size': 600, 'success': True, 'utility': 2540.748670849144}
# (03-04) 19:00:18 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:00:19 INFO     [client.py:17] Start to train (CLIENT: 2) ...
# (03-04) 19:00:22 INFO     [client.py:187] Training of (CLIENT: 2) completes, {'clientId': 2, 'moving_loss': 3.698958115841707, 'trained_size': 600, 'success': True, 'utility': 2274.132320557489}
# (03-04) 19:00:22 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:00:23 INFO     [client.py:17] Start to train (CLIENT: 3) ...
# (03-04) 19:00:26 INFO     [client.py:187] Training of (CLIENT: 3) completes, {'clientId': 3, 'moving_loss': 5.585061749169056, 'trained_size': 600, 'success': True, 'utility': 5945.434712182724}
# (03-04) 19:00:26 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:00:27 INFO     [client.py:17] Start to train (CLIENT: 4) ...
# (03-04) 19:00:31 INFO     [client.py:187] Training of (CLIENT: 4) completes, {'clientId': 4, 'moving_loss': 4.955509286161629, 'trained_size': 600, 'success': True, 'utility': 5305.577428286064}
# (03-04) 19:00:31 INFO     [executor.py:149] Received GRPC UpdateModel request
# (03-04) 19:00:31 INFO     [executor.py:205] Received GRPC Test request
# (03-04) 19:00:35 INFO     [utils_model.py:365] Rank 1: Test set: Average loss: 2.7138, Top-1 Accuracy: 1000.0/10000 (0.1), Top-5 Accuracy: 0.5
# (03-04) 19:00:35 INFO     [executor.py:293] After aggregation epoch 5, CumulTime 80.5725, eval_time 4.3604, test_loss 2.7138, test_accuracy 10.00%, test_5_accuracy 50.00%
#
# (03-04) 19:00:35 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:00:36 INFO     [client.py:17] Start to train (CLIENT: 1) ...
# (03-04) 19:00:39 INFO     [client.py:187] Training of (CLIENT: 1) completes, {'clientId': 1, 'moving_loss': 3.2707472533574076, 'trained_size': 600, 'success': True, 'utility': 2227.6138230670535}
# (03-04) 19:00:39 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:00:39 INFO     [client.py:17] Start to train (CLIENT: 2) ...
# (03-04) 19:00:43 INFO     [client.py:187] Training of (CLIENT: 2) completes, {'clientId': 2, 'moving_loss': 3.3100625099085925, 'trained_size': 600, 'success': True, 'utility': 2481.3448414820673}
# (03-04) 19:00:43 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:00:43 INFO     [client.py:17] Start to train (CLIENT: 3) ...
# (03-04) 19:00:47 INFO     [client.py:187] Training of (CLIENT: 3) completes, {'clientId': 3, 'moving_loss': 3.401243356481161, 'trained_size': 600, 'success': True, 'utility': 2405.9800404336133}
# (03-04) 19:00:47 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:00:47 INFO     [client.py:17] Start to train (CLIENT: 4) ...
# (03-04) 19:00:51 INFO     [client.py:187] Training of (CLIENT: 4) completes, {'clientId': 4, 'moving_loss': 2.862476760428658, 'trained_size': 600, 'success': True, 'utility': 1963.7636954736715}
# (03-04) 19:00:51 INFO     [executor.py:149] Received GRPC UpdateModel request
# (03-04) 19:00:51 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:00:52 INFO     [client.py:17] Start to train (CLIENT: 1) ...
# (03-04) 19:00:55 INFO     [client.py:187] Training of (CLIENT: 1) completes, {'clientId': 1, 'moving_loss': 3.266853203517368, 'trained_size': 600, 'success': True, 'utility': 1732.60615963363}
# (03-04) 19:00:55 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:00:55 INFO     [client.py:17] Start to train (CLIENT: 2) ...
# (03-04) 19:00:59 INFO     [client.py:187] Training of (CLIENT: 2) completes, {'clientId': 2, 'moving_loss': 2.855396778266464, 'trained_size': 600, 'success': True, 'utility': 1653.382626893338}
# (03-04) 19:00:59 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:00:59 INFO     [client.py:17] Start to train (CLIENT: 3) ...
# (03-04) 19:01:03 INFO     [client.py:187] Training of (CLIENT: 3) completes, {'clientId': 3, 'moving_loss': 2.831089434529156, 'trained_size': 600, 'success': True, 'utility': 2011.3035998657697}
# (03-04) 19:01:03 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:01:03 INFO     [client.py:17] Start to train (CLIENT: 4) ...
# (03-04) 19:01:07 INFO     [client.py:187] Training of (CLIENT: 4) completes, {'clientId': 4, 'moving_loss': 3.042358627351506, 'trained_size': 600, 'success': True, 'utility': 1806.6110785048413}
# (03-04) 19:01:08 INFO     [executor.py:149] Received GRPC UpdateModel request
# (03-04) 19:01:08 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:01:08 INFO     [client.py:17] Start to train (CLIENT: 1) ...
# (03-04) 19:01:12 INFO     [client.py:187] Training of (CLIENT: 1) completes, {'clientId': 1, 'moving_loss': 2.5548434176129193, 'trained_size': 600, 'success': True, 'utility': 1740.3220917255137}
# (03-04) 19:01:12 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:01:12 INFO     [client.py:17] Start to train (CLIENT: 2) ...
# (03-04) 19:01:16 INFO     [client.py:187] Training of (CLIENT: 2) completes, {'clientId': 2, 'moving_loss': 2.537354787879475, 'trained_size': 600, 'success': True, 'utility': 1490.9903545763884}
# (03-04) 19:01:16 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:01:16 INFO     [client.py:17] Start to train (CLIENT: 3) ...
# (03-04) 19:01:20 INFO     [client.py:187] Training of (CLIENT: 3) completes, {'clientId': 3, 'moving_loss': 2.7060836902554817, 'trained_size': 600, 'success': True, 'utility': 1910.714230959362}
# (03-04) 19:01:20 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:01:20 INFO     [client.py:17] Start to train (CLIENT: 4) ...
# (03-04) 19:01:24 INFO     [client.py:187] Training of (CLIENT: 4) completes, {'clientId': 4, 'moving_loss': 2.5772996829733055, 'trained_size': 600, 'success': True, 'utility': 1621.9429855720678}
# (03-04) 19:01:25 INFO     [executor.py:149] Received GRPC UpdateModel request
# (03-04) 19:01:25 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:01:25 INFO     [client.py:17] Start to train (CLIENT: 1) ...
# (03-04) 19:01:29 INFO     [client.py:187] Training of (CLIENT: 1) completes, {'clientId': 1, 'moving_loss': 2.5003501887888038, 'trained_size': 600, 'success': True, 'utility': 1684.2653642459697}
# (03-04) 19:01:29 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:01:29 INFO     [client.py:17] Start to train (CLIENT: 2) ...
# (03-04) 19:01:33 INFO     [client.py:187] Training of (CLIENT: 2) completes, {'clientId': 2, 'moving_loss': 2.335390408034984, 'trained_size': 600, 'success': True, 'utility': 1778.1469914553643}
# (03-04) 19:01:33 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:01:33 INFO     [client.py:17] Start to train (CLIENT: 3) ...
# (03-04) 19:01:37 INFO     [client.py:187] Training of (CLIENT: 3) completes, {'clientId': 3, 'moving_loss': 2.497344985942037, 'trained_size': 600, 'success': True, 'utility': 1546.2605788910164}
# (03-04) 19:01:37 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:01:37 INFO     [client.py:17] Start to train (CLIENT: 4) ...
# (03-04) 19:01:41 INFO     [client.py:187] Training of (CLIENT: 4) completes, {'clientId': 4, 'moving_loss': 2.5425368854360304, 'trained_size': 600, 'success': True, 'utility': 1660.8008981256883}
# (03-04) 19:01:41 INFO     [executor.py:149] Received GRPC UpdateModel request
# (03-04) 19:01:42 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:01:42 INFO     [client.py:17] Start to train (CLIENT: 1) ...
# (03-04) 19:01:45 INFO     [client.py:187] Training of (CLIENT: 1) completes, {'clientId': 1, 'moving_loss': 2.415195213033262, 'trained_size': 600, 'success': True, 'utility': 1786.98568992865}
# (03-04) 19:01:45 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:01:46 INFO     [client.py:17] Start to train (CLIENT: 2) ...
# (03-04) 19:01:49 INFO     [client.py:187] Training of (CLIENT: 2) completes, {'clientId': 2, 'moving_loss': 2.4208433446094118, 'trained_size': 600, 'success': True, 'utility': 1353.127631099204}
# (03-04) 19:01:49 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:01:49 INFO     [client.py:17] Start to train (CLIENT: 3) ...
# (03-04) 19:01:53 INFO     [client.py:187] Training of (CLIENT: 3) completes, {'clientId': 3, 'moving_loss': 2.418253155498097, 'trained_size': 600, 'success': True, 'utility': 1981.8749601143572}
# (03-04) 19:01:53 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:01:54 INFO     [client.py:17] Start to train (CLIENT: 4) ...
# (03-04) 19:01:58 INFO     [client.py:187] Training of (CLIENT: 4) completes, {'clientId': 4, 'moving_loss': 2.340269607021022, 'trained_size': 600, 'success': True, 'utility': 1483.7491945987733}
# (03-04) 19:01:58 INFO     [executor.py:149] Received GRPC UpdateModel request
# (03-04) 19:01:58 INFO     [executor.py:205] Received GRPC Test request
# (03-04) 19:02:03 INFO     [utils_model.py:365] Rank 1: Test set: Average loss: 2.2961, Top-1 Accuracy: 1501.0/10000 (0.1501), Top-5 Accuracy: 0.6402
# (03-04) 19:02:03 INFO     [executor.py:293] After aggregation epoch 10, CumulTime 167.7488, eval_time 4.3315, test_loss 2.2961, test_accuracy 15.01%, test_5_accuracy 64.02%
#
# (03-04) 19:02:03 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:02:03 INFO     [client.py:17] Start to train (CLIENT: 1) ...
# (03-04) 19:02:07 INFO     [client.py:187] Training of (CLIENT: 1) completes, {'clientId': 1, 'moving_loss': 2.3549062860273127, 'trained_size': 600, 'success': True, 'utility': 1466.2666661366375}
# (03-04) 19:02:07 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:02:07 INFO     [client.py:17] Start to train (CLIENT: 2) ...
# (03-04) 19:02:10 INFO     [client.py:187] Training of (CLIENT: 2) completes, {'clientId': 2, 'moving_loss': 2.1950617674504946, 'trained_size': 600, 'success': True, 'utility': 1506.5332875586885}
# (03-04) 19:02:10 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:02:10 INFO     [client.py:17] Start to train (CLIENT: 3) ...
# (03-04) 19:02:15 INFO     [client.py:187] Training of (CLIENT: 3) completes, {'clientId': 3, 'moving_loss': 2.3166805121342007, 'trained_size': 600, 'success': True, 'utility': 1325.011609419012}
# (03-04) 19:02:15 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:02:15 INFO     [client.py:17] Start to train (CLIENT: 4) ...
# (03-04) 19:02:19 INFO     [client.py:187] Training of (CLIENT: 4) completes, {'clientId': 4, 'moving_loss': 2.4723577792963387, 'trained_size': 600, 'success': True, 'utility': 1776.1354232948072}
# (03-04) 19:02:19 INFO     [executor.py:149] Received GRPC UpdateModel request
# (03-04) 19:02:19 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:02:19 INFO     [client.py:17] Start to train (CLIENT: 1) ...
# (03-04) 19:02:23 INFO     [client.py:187] Training of (CLIENT: 1) completes, {'clientId': 1, 'moving_loss': 2.304801041390954, 'trained_size': 600, 'success': True, 'utility': 1535.8823206695893}
# (03-04) 19:02:23 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:02:24 INFO     [client.py:17] Start to train (CLIENT: 2) ...
# (03-04) 19:02:28 INFO     [client.py:187] Training of (CLIENT: 2) completes, {'clientId': 2, 'moving_loss': 2.3828599152910512, 'trained_size': 600, 'success': True, 'utility': 1514.6184584414445}
# (03-04) 19:02:28 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:02:28 INFO     [client.py:17] Start to train (CLIENT: 3) ...
# (03-04) 19:02:32 INFO     [client.py:187] Training of (CLIENT: 3) completes, {'clientId': 3, 'moving_loss': 2.375393155409973, 'trained_size': 600, 'success': True, 'utility': 1456.2818429807087}
# (03-04) 19:02:32 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:02:32 INFO     [client.py:17] Start to train (CLIENT: 4) ...
# (03-04) 19:02:36 INFO     [client.py:187] Training of (CLIENT: 4) completes, {'clientId': 4, 'moving_loss': 2.3304627750416005, 'trained_size': 600, 'success': True, 'utility': 1535.5820931533742}
# (03-04) 19:02:36 INFO     [executor.py:149] Received GRPC UpdateModel request
# (03-04) 19:02:36 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:02:36 INFO     [client.py:17] Start to train (CLIENT: 1) ...
# (03-04) 19:02:40 INFO     [client.py:187] Training of (CLIENT: 1) completes, {'clientId': 1, 'moving_loss': 2.1908794326446266, 'trained_size': 600, 'success': True, 'utility': 1314.7367253243654}
# (03-04) 19:02:40 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:02:40 INFO     [client.py:17] Start to train (CLIENT: 2) ...
# (03-04) 19:02:44 INFO     [client.py:187] Training of (CLIENT: 2) completes, {'clientId': 2, 'moving_loss': 2.2584207735292345, 'trained_size': 600, 'success': True, 'utility': 1508.9038467215157}
# (03-04) 19:02:44 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:02:44 INFO     [client.py:17] Start to train (CLIENT: 3) ...
# (03-04) 19:02:48 INFO     [client.py:187] Training of (CLIENT: 3) completes, {'clientId': 3, 'moving_loss': 2.295303288840891, 'trained_size': 600, 'success': True, 'utility': 1482.1924533448782}
# (03-04) 19:02:48 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:02:48 INFO     [client.py:17] Start to train (CLIENT: 4) ...
# (03-04) 19:02:52 INFO     [client.py:187] Training of (CLIENT: 4) completes, {'clientId': 4, 'moving_loss': 2.3188039399682707, 'trained_size': 600, 'success': True, 'utility': 1481.1851231294972}
# (03-04) 19:02:52 INFO     [executor.py:149] Received GRPC UpdateModel request
# (03-04) 19:02:52 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:02:52 INFO     [client.py:17] Start to train (CLIENT: 1) ...
# (03-04) 19:02:56 INFO     [client.py:187] Training of (CLIENT: 1) completes, {'clientId': 1, 'moving_loss': 2.2343263967437323, 'trained_size': 600, 'success': True, 'utility': 1578.1255704852008}
# (03-04) 19:02:56 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:02:56 INFO     [client.py:17] Start to train (CLIENT: 2) ...
# (03-04) 19:03:00 INFO     [client.py:187] Training of (CLIENT: 2) completes, {'clientId': 2, 'moving_loss': 2.2647111955608263, 'trained_size': 600, 'success': True, 'utility': 1668.398073681557}
# (03-04) 19:03:00 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:03:00 INFO     [client.py:17] Start to train (CLIENT: 3) ...
# (03-04) 19:03:04 INFO     [client.py:187] Training of (CLIENT: 3) completes, {'clientId': 3, 'moving_loss': 2.250899268712639, 'trained_size': 600, 'success': True, 'utility': 1434.2170489987004}
# (03-04) 19:03:04 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:03:04 INFO     [client.py:17] Start to train (CLIENT: 4) ...
# (03-04) 19:03:08 INFO     [client.py:187] Training of (CLIENT: 4) completes, {'clientId': 4, 'moving_loss': 2.385804536986689, 'trained_size': 600, 'success': True, 'utility': 1563.52496627369}
# (03-04) 19:03:09 INFO     [executor.py:149] Received GRPC UpdateModel request
# (03-04) 19:03:09 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:03:09 INFO     [client.py:17] Start to train (CLIENT: 1) ...
# (03-04) 19:03:13 INFO     [client.py:187] Training of (CLIENT: 1) completes, {'clientId': 1, 'moving_loss': 2.261032069521521, 'trained_size': 600, 'success': True, 'utility': 1405.5182046006125}
# (03-04) 19:03:13 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:03:13 INFO     [client.py:17] Start to train (CLIENT: 2) ...
# (03-04) 19:03:17 INFO     [client.py:187] Training of (CLIENT: 2) completes, {'clientId': 2, 'moving_loss': 2.2476757832233494, 'trained_size': 600, 'success': True, 'utility': 1504.5573392711372}
# (03-04) 19:03:17 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:03:17 INFO     [client.py:17] Start to train (CLIENT: 3) ...
# (03-04) 19:03:21 INFO     [client.py:187] Training of (CLIENT: 3) completes, {'clientId': 3, 'moving_loss': 2.264389253164051, 'trained_size': 600, 'success': True, 'utility': 1564.0058241145477}
# (03-04) 19:03:21 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:03:21 INFO     [client.py:17] Start to train (CLIENT: 4) ...
# (03-04) 19:03:25 INFO     [client.py:187] Training of (CLIENT: 4) completes, {'clientId': 4, 'moving_loss': 2.345817700846023, 'trained_size': 600, 'success': True, 'utility': 1382.9925349358778}
# (03-04) 19:03:25 INFO     [executor.py:149] Received GRPC UpdateModel request
# (03-04) 19:03:25 INFO     [executor.py:205] Received GRPC Test request
# (03-04) 19:03:30 INFO     [utils_model.py:365] Rank 1: Test set: Average loss: 2.2084, Top-1 Accuracy: 1913.0/10000 (0.1913), Top-5 Accuracy: 0.6651
# (03-04) 19:03:30 INFO     [executor.py:293] After aggregation epoch 15, CumulTime 254.8408, eval_time 4.3256, test_loss 2.2084, test_accuracy 19.13%, test_5_accuracy 66.51%
#
# (03-04) 19:03:30 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:03:30 INFO     [client.py:17] Start to train (CLIENT: 1) ...
# (03-04) 19:03:34 INFO     [client.py:187] Training of (CLIENT: 1) completes, {'clientId': 1, 'moving_loss': 2.123716077123185, 'trained_size': 600, 'success': True, 'utility': 1430.0789941802589}
# (03-04) 19:03:34 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:03:34 INFO     [client.py:17] Start to train (CLIENT: 2) ...
# (03-04) 19:03:38 INFO     [client.py:187] Training of (CLIENT: 2) completes, {'clientId': 2, 'moving_loss': 2.269949128839266, 'trained_size': 600, 'success': True, 'utility': 1572.8569959001973}
# (03-04) 19:03:38 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:03:38 INFO     [client.py:17] Start to train (CLIENT: 3) ...
# (03-04) 19:03:42 INFO     [client.py:187] Training of (CLIENT: 3) completes, {'clientId': 3, 'moving_loss': 2.154669296875331, 'trained_size': 600, 'success': True, 'utility': 1420.5006313147305}
# (03-04) 19:03:42 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:03:42 INFO     [client.py:17] Start to train (CLIENT: 4) ...
# (03-04) 19:03:46 INFO     [client.py:187] Training of (CLIENT: 4) completes, {'clientId': 4, 'moving_loss': 2.144359698100791, 'trained_size': 600, 'success': True, 'utility': 1365.29748396522}
# (03-04) 19:03:46 INFO     [executor.py:149] Received GRPC UpdateModel request
# (03-04) 19:03:46 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:03:47 INFO     [client.py:17] Start to train (CLIENT: 1) ...
# (03-04) 19:03:50 INFO     [client.py:187] Training of (CLIENT: 1) completes, {'clientId': 1, 'moving_loss': 2.102855806035112, 'trained_size': 600, 'success': True, 'utility': 1274.6341017680618}
# (03-04) 19:03:50 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:03:50 INFO     [client.py:17] Start to train (CLIENT: 2) ...
# (03-04) 19:03:54 INFO     [client.py:187] Training of (CLIENT: 2) completes, {'clientId': 2, 'moving_loss': 2.394839001783787, 'trained_size': 600, 'success': True, 'utility': 1645.1710697777712}
# (03-04) 19:03:54 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:03:54 INFO     [client.py:17] Start to train (CLIENT: 3) ...
# (03-04) 19:03:58 INFO     [client.py:187] Training of (CLIENT: 3) completes, {'clientId': 3, 'moving_loss': 2.21188927581919, 'trained_size': 600, 'success': True, 'utility': 1396.9577181697314}
# (03-04) 19:03:58 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:03:59 INFO     [client.py:17] Start to train (CLIENT: 4) ...
# (03-04) 19:04:03 INFO     [client.py:187] Training of (CLIENT: 4) completes, {'clientId': 4, 'moving_loss': 2.107037647722496, 'trained_size': 600, 'success': True, 'utility': 1344.8555227178956}
# (03-04) 19:04:03 INFO     [executor.py:149] Received GRPC UpdateModel request
# (03-04) 19:04:03 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:04:03 INFO     [client.py:17] Start to train (CLIENT: 1) ...
# (03-04) 19:04:07 INFO     [client.py:187] Training of (CLIENT: 1) completes, {'clientId': 1, 'moving_loss': 2.1720451101022604, 'trained_size': 600, 'success': True, 'utility': 1380.5815644659626}
# (03-04) 19:04:07 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:04:07 INFO     [client.py:17] Start to train (CLIENT: 2) ...
# (03-04) 19:04:11 INFO     [client.py:187] Training of (CLIENT: 2) completes, {'clientId': 2, 'moving_loss': 2.1201380600425055, 'trained_size': 600, 'success': True, 'utility': 1275.2148493159186}
# (03-04) 19:04:11 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:04:11 INFO     [client.py:17] Start to train (CLIENT: 3) ...
# (03-04) 19:04:15 INFO     [client.py:187] Training of (CLIENT: 3) completes, {'clientId': 3, 'moving_loss': 2.1821282381523934, 'trained_size': 600, 'success': True, 'utility': 1459.9747272258583}
# (03-04) 19:04:15 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:04:15 INFO     [client.py:17] Start to train (CLIENT: 4) ...
# (03-04) 19:04:19 INFO     [client.py:187] Training of (CLIENT: 4) completes, {'clientId': 4, 'moving_loss': 2.1758023567242, 'trained_size': 600, 'success': True, 'utility': 1476.699989569273}
# (03-04) 19:04:19 INFO     [executor.py:149] Received GRPC UpdateModel request
# (03-04) 19:04:19 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:04:20 INFO     [client.py:17] Start to train (CLIENT: 1) ...
# (03-04) 19:04:23 INFO     [client.py:187] Training of (CLIENT: 1) completes, {'clientId': 1, 'moving_loss': 2.035437998136092, 'trained_size': 600, 'success': True, 'utility': 1364.2217616224796}
# (03-04) 19:04:23 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:04:23 INFO     [client.py:17] Start to train (CLIENT: 2) ...
# (03-04) 19:04:27 INFO     [client.py:187] Training of (CLIENT: 2) completes, {'clientId': 2, 'moving_loss': 2.1701135820429296, 'trained_size': 600, 'success': True, 'utility': 1518.8415417186968}
# (03-04) 19:04:27 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:04:27 INFO     [client.py:17] Start to train (CLIENT: 3) ...
# (03-04) 19:04:31 INFO     [client.py:187] Training of (CLIENT: 3) completes, {'clientId': 3, 'moving_loss': 2.085135807932731, 'trained_size': 600, 'success': True, 'utility': 1731.0151182853706}
# (03-04) 19:04:31 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:04:32 INFO     [client.py:17] Start to train (CLIENT: 4) ...
# (03-04) 19:04:35 INFO     [client.py:187] Training of (CLIENT: 4) completes, {'clientId': 4, 'moving_loss': 2.1527981822556526, 'trained_size': 600, 'success': True, 'utility': 1342.2939543433033}
# (03-04) 19:04:36 INFO     [executor.py:149] Received GRPC UpdateModel request
# (03-04) 19:04:36 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:04:36 INFO     [client.py:17] Start to train (CLIENT: 1) ...
# (03-04) 19:04:40 INFO     [client.py:187] Training of (CLIENT: 1) completes, {'clientId': 1, 'moving_loss': 2.014719032433945, 'trained_size': 600, 'success': True, 'utility': 1311.8465221580182}
# (03-04) 19:04:40 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:04:40 INFO     [client.py:17] Start to train (CLIENT: 2) ...
# (03-04) 19:04:44 INFO     [client.py:187] Training of (CLIENT: 2) completes, {'clientId': 2, 'moving_loss': 2.281043129862417, 'trained_size': 600, 'success': True, 'utility': 1451.1360896981923}
# (03-04) 19:04:44 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:04:44 INFO     [client.py:17] Start to train (CLIENT: 3) ...
# (03-04) 19:04:48 INFO     [client.py:187] Training of (CLIENT: 3) completes, {'clientId': 3, 'moving_loss': 2.0633856769043533, 'trained_size': 600, 'success': True, 'utility': 1368.8653777734285}
# (03-04) 19:04:48 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:04:48 INFO     [client.py:17] Start to train (CLIENT: 4) ...
# (03-04) 19:04:52 INFO     [client.py:187] Training of (CLIENT: 4) completes, {'clientId': 4, 'moving_loss': 2.090589558293021, 'trained_size': 600, 'success': True, 'utility': 1230.4730862374379}
# (03-04) 19:04:52 INFO     [executor.py:149] Received GRPC UpdateModel request
# (03-04) 19:04:52 INFO     [executor.py:205] Received GRPC Test request
# (03-04) 19:04:57 INFO     [utils_model.py:365] Rank 1: Test set: Average loss: 1.9998, Top-1 Accuracy: 2700.0/10000 (0.27), Top-5 Accuracy: 0.794
# (03-04) 19:04:57 INFO     [executor.py:293] After aggregation epoch 20, CumulTime 342.1071, eval_time 4.3824, test_loss 1.9998, test_accuracy 27.00%, test_5_accuracy 79.40%
#
# (03-04) 19:04:57 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:04:57 INFO     [client.py:17] Start to train (CLIENT: 1) ...
# (03-04) 19:05:01 INFO     [client.py:187] Training of (CLIENT: 1) completes, {'clientId': 1, 'moving_loss': 2.0481677621921603, 'trained_size': 600, 'success': True, 'utility': 1478.4253933249317}
# (03-04) 19:05:01 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:05:01 INFO     [client.py:17] Start to train (CLIENT: 2) ...
# (03-04) 19:05:05 INFO     [client.py:187] Training of (CLIENT: 2) completes, {'clientId': 2, 'moving_loss': 2.056033548831132, 'trained_size': 600, 'success': True, 'utility': 1297.3380999680578}
# (03-04) 19:05:05 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:05:05 INFO     [client.py:17] Start to train (CLIENT: 3) ...
# (03-04) 19:05:09 INFO     [client.py:187] Training of (CLIENT: 3) completes, {'clientId': 3, 'moving_loss': 2.060891474855394, 'trained_size': 600, 'success': True, 'utility': 1475.9031094150932}
# (03-04) 19:05:09 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:05:09 INFO     [client.py:17] Start to train (CLIENT: 4) ...
# (03-04) 19:05:13 INFO     [client.py:187] Training of (CLIENT: 4) completes, {'clientId': 4, 'moving_loss': 2.2158287006742388, 'trained_size': 600, 'success': True, 'utility': 1291.0846382172736}
# (03-04) 19:05:13 INFO     [executor.py:149] Received GRPC UpdateModel request
# (03-04) 19:05:13 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:05:13 INFO     [client.py:17] Start to train (CLIENT: 1) ...
# (03-04) 19:05:17 INFO     [client.py:187] Training of (CLIENT: 1) completes, {'clientId': 1, 'moving_loss': 2.09353642927621, 'trained_size': 600, 'success': True, 'utility': 1424.8737624746068}
# (03-04) 19:05:17 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:05:17 INFO     [client.py:17] Start to train (CLIENT: 2) ...
# (03-04) 19:05:21 INFO     [client.py:187] Training of (CLIENT: 2) completes, {'clientId': 2, 'moving_loss': 2.1035526290990383, 'trained_size': 600, 'success': True, 'utility': 1378.6350780575794}
# (03-04) 19:05:21 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:05:21 INFO     [client.py:17] Start to train (CLIENT: 3) ...
# (03-04) 19:05:25 INFO     [client.py:187] Training of (CLIENT: 3) completes, {'clientId': 3, 'moving_loss': 2.1579087784150435, 'trained_size': 600, 'success': True, 'utility': 1396.0633464126092}
# (03-04) 19:05:25 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:05:25 INFO     [client.py:17] Start to train (CLIENT: 4) ...
# (03-04) 19:05:29 INFO     [client.py:187] Training of (CLIENT: 4) completes, {'clientId': 4, 'moving_loss': 2.037446342941732, 'trained_size': 600, 'success': True, 'utility': 1154.0421149385427}
# (03-04) 19:05:30 INFO     [executor.py:149] Received GRPC UpdateModel request
# (03-04) 19:05:30 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:05:30 INFO     [client.py:17] Start to train (CLIENT: 1) ...
# (03-04) 19:05:34 INFO     [client.py:187] Training of (CLIENT: 1) completes, {'clientId': 1, 'moving_loss': 2.066558621155848, 'trained_size': 600, 'success': True, 'utility': 1338.3511201292906}
# (03-04) 19:05:34 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:05:34 INFO     [client.py:17] Start to train (CLIENT: 2) ...
# (03-04) 19:05:38 INFO     [client.py:187] Training of (CLIENT: 2) completes, {'clientId': 2, 'moving_loss': 2.207615832531525, 'trained_size': 600, 'success': True, 'utility': 1602.5983151855885}
# (03-04) 19:05:38 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:05:38 INFO     [client.py:17] Start to train (CLIENT: 3) ...
# (03-04) 19:05:42 INFO     [client.py:187] Training of (CLIENT: 3) completes, {'clientId': 3, 'moving_loss': 2.038092442291111, 'trained_size': 600, 'success': True, 'utility': 1289.460686787126}
# (03-04) 19:05:42 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:05:42 INFO     [client.py:17] Start to train (CLIENT: 4) ...
# (03-04) 19:05:46 INFO     [client.py:187] Training of (CLIENT: 4) completes, {'clientId': 4, 'moving_loss': 2.0531947550882927, 'trained_size': 600, 'success': True, 'utility': 1361.3531408998242}
# (03-04) 19:05:46 INFO     [executor.py:149] Received GRPC UpdateModel request
# (03-04) 19:05:47 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:05:47 INFO     [client.py:17] Start to train (CLIENT: 1) ...
# (03-04) 19:05:50 INFO     [client.py:187] Training of (CLIENT: 1) completes, {'clientId': 1, 'moving_loss': 2.026284462005707, 'trained_size': 600, 'success': True, 'utility': 1246.3758564618656}
# (03-04) 19:05:50 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:05:51 INFO     [client.py:17] Start to train (CLIENT: 2) ...
# (03-04) 19:05:54 INFO     [client.py:187] Training of (CLIENT: 2) completes, {'clientId': 2, 'moving_loss': 1.9268038063247972, 'trained_size': 600, 'success': True, 'utility': 1295.8970141129037}
# (03-04) 19:05:54 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:05:54 INFO     [client.py:17] Start to train (CLIENT: 3) ...
# (03-04) 19:05:58 INFO     [client.py:187] Training of (CLIENT: 3) completes, {'clientId': 3, 'moving_loss': 2.0349676225029287, 'trained_size': 600, 'success': True, 'utility': 1259.66646952994}
# (03-04) 19:05:58 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:05:58 INFO     [client.py:17] Start to train (CLIENT: 4) ...
# (03-04) 19:06:02 INFO     [client.py:187] Training of (CLIENT: 4) completes, {'clientId': 4, 'moving_loss': 2.0335668811397376, 'trained_size': 600, 'success': True, 'utility': 1497.292954195968}
# (03-04) 19:06:02 INFO     [executor.py:149] Received GRPC UpdateModel request
# (03-04) 19:06:03 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:06:03 INFO     [client.py:17] Start to train (CLIENT: 1) ...
# (03-04) 19:06:07 INFO     [client.py:187] Training of (CLIENT: 1) completes, {'clientId': 1, 'moving_loss': 2.0359278051240572, 'trained_size': 600, 'success': True, 'utility': 1470.2886276668564}
# (03-04) 19:06:07 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:06:07 INFO     [client.py:17] Start to train (CLIENT: 2) ...
# (03-04) 19:06:11 INFO     [client.py:187] Training of (CLIENT: 2) completes, {'clientId': 2, 'moving_loss': 2.109886064693276, 'trained_size': 600, 'success': True, 'utility': 1191.1139724312536}
# (03-04) 19:06:11 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:06:11 INFO     [client.py:17] Start to train (CLIENT: 3) ...
# (03-04) 19:06:14 INFO     [client.py:187] Training of (CLIENT: 3) completes, {'clientId': 3, 'moving_loss': 2.0413252151263945, 'trained_size': 600, 'success': True, 'utility': 1399.1919617279573}
# (03-04) 19:06:14 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:06:15 INFO     [client.py:17] Start to train (CLIENT: 4) ...
# (03-04) 19:06:18 INFO     [client.py:187] Training of (CLIENT: 4) completes, {'clientId': 4, 'moving_loss': 2.063987534519153, 'trained_size': 600, 'success': True, 'utility': 1280.1896187955108}
# (03-04) 19:06:19 INFO     [executor.py:149] Received GRPC UpdateModel request
# (03-04) 19:06:19 INFO     [executor.py:205] Received GRPC Test request
# (03-04) 19:06:23 INFO     [utils_model.py:365] Rank 1: Test set: Average loss: 2.0768, Top-1 Accuracy: 2386.0/10000 (0.2386), Top-5 Accuracy: 0.7521
# (03-04) 19:06:23 INFO     [executor.py:293] After aggregation epoch 25, CumulTime 428.2898, eval_time 4.1996, test_loss 2.0768, test_accuracy 23.86%, test_5_accuracy 75.21%
#
# (03-04) 19:06:23 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:06:23 INFO     [client.py:17] Start to train (CLIENT: 1) ...
# (03-04) 19:06:27 INFO     [client.py:187] Training of (CLIENT: 1) completes, {'clientId': 1, 'moving_loss': 2.116516560301071, 'trained_size': 600, 'success': True, 'utility': 1402.2633183446426}
# (03-04) 19:06:27 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:06:27 INFO     [client.py:17] Start to train (CLIENT: 2) ...
# (03-04) 19:06:31 INFO     [client.py:187] Training of (CLIENT: 2) completes, {'clientId': 2, 'moving_loss': 2.0701645234837036, 'trained_size': 600, 'success': True, 'utility': 1376.9202554481833}
# (03-04) 19:06:31 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:06:31 INFO     [client.py:17] Start to train (CLIENT: 3) ...
# (03-04) 19:06:35 INFO     [client.py:187] Training of (CLIENT: 3) completes, {'clientId': 3, 'moving_loss': 2.0667062290212903, 'trained_size': 600, 'success': True, 'utility': 1439.1957985134122}
# (03-04) 19:06:35 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:06:35 INFO     [client.py:17] Start to train (CLIENT: 4) ...
# (03-04) 19:06:39 INFO     [client.py:187] Training of (CLIENT: 4) completes, {'clientId': 4, 'moving_loss': 2.0114117999769174, 'trained_size': 600, 'success': True, 'utility': 1305.351123900438}
# (03-04) 19:06:40 INFO     [executor.py:149] Received GRPC UpdateModel request
# (03-04) 19:06:40 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:06:40 INFO     [client.py:17] Start to train (CLIENT: 1) ...
# (03-04) 19:06:44 INFO     [client.py:187] Training of (CLIENT: 1) completes, {'clientId': 1, 'moving_loss': 1.9733778578327215, 'trained_size': 600, 'success': True, 'utility': 1257.6658382659584}
# (03-04) 19:06:44 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:06:44 INFO     [client.py:17] Start to train (CLIENT: 2) ...
# (03-04) 19:06:48 INFO     [client.py:187] Training of (CLIENT: 2) completes, {'clientId': 2, 'moving_loss': 2.002598832367345, 'trained_size': 600, 'success': True, 'utility': 1138.6594520139593}
# (03-04) 19:06:48 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:06:48 INFO     [client.py:17] Start to train (CLIENT: 3) ...
# (03-04) 19:06:52 INFO     [client.py:187] Training of (CLIENT: 3) completes, {'clientId': 3, 'moving_loss': 2.0041657660853898, 'trained_size': 600, 'success': True, 'utility': 1300.0235158909077}
# (03-04) 19:06:52 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:06:52 INFO     [client.py:17] Start to train (CLIENT: 4) ...
# (03-04) 19:06:56 INFO     [client.py:187] Training of (CLIENT: 4) completes, {'clientId': 4, 'moving_loss': 2.2596350499005604, 'trained_size': 600, 'success': True, 'utility': 1528.513945378608}
# (03-04) 19:06:56 INFO     [executor.py:149] Received GRPC UpdateModel request
# (03-04) 19:06:56 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:06:56 INFO     [client.py:17] Start to train (CLIENT: 1) ...
# (03-04) 19:07:00 INFO     [client.py:187] Training of (CLIENT: 1) completes, {'clientId': 1, 'moving_loss': 1.9714559314104667, 'trained_size': 600, 'success': True, 'utility': 1264.4251114602284}
# (03-04) 19:07:00 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:07:00 INFO     [client.py:17] Start to train (CLIENT: 2) ...
# (03-04) 19:07:04 INFO     [client.py:187] Training of (CLIENT: 2) completes, {'clientId': 2, 'moving_loss': 2.0917116661729107, 'trained_size': 600, 'success': True, 'utility': 1293.9057448495837}
# (03-04) 19:07:04 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:07:04 INFO     [client.py:17] Start to train (CLIENT: 3) ...
# (03-04) 19:07:08 INFO     [client.py:187] Training of (CLIENT: 3) completes, {'clientId': 3, 'moving_loss': 2.0267999837076633, 'trained_size': 600, 'success': True, 'utility': 1304.679444949351}
# (03-04) 19:07:08 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:07:08 INFO     [client.py:17] Start to train (CLIENT: 4) ...
# (03-04) 19:07:12 INFO     [client.py:187] Training of (CLIENT: 4) completes, {'clientId': 4, 'moving_loss': 2.104859545471251, 'trained_size': 600, 'success': True, 'utility': 1515.3129181396878}
# (03-04) 19:07:12 INFO     [executor.py:149] Received GRPC UpdateModel request
# (03-04) 19:07:13 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:07:13 INFO     [client.py:17] Start to train (CLIENT: 1) ...
# (03-04) 19:07:16 INFO     [client.py:187] Training of (CLIENT: 1) completes, {'clientId': 1, 'moving_loss': 2.0207189386044533, 'trained_size': 600, 'success': True, 'utility': 1418.8653047783168}
# (03-04) 19:07:16 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:07:17 INFO     [client.py:17] Start to train (CLIENT: 2) ...
# (03-04) 19:07:20 INFO     [client.py:187] Training of (CLIENT: 2) completes, {'clientId': 2, 'moving_loss': 1.9922192840576463, 'trained_size': 600, 'success': True, 'utility': 1165.6195607929883}
# (03-04) 19:07:20 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:07:20 INFO     [client.py:17] Start to train (CLIENT: 3) ...
# (03-04) 19:07:24 INFO     [client.py:187] Training of (CLIENT: 3) completes, {'clientId': 3, 'moving_loss': 2.082599841291858, 'trained_size': 600, 'success': True, 'utility': 1508.5314490511985}
# (03-04) 19:07:24 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:07:24 INFO     [client.py:17] Start to train (CLIENT: 4) ...
# (03-04) 19:07:29 INFO     [client.py:187] Training of (CLIENT: 4) completes, {'clientId': 4, 'moving_loss': 1.978436176537425, 'trained_size': 600, 'success': True, 'utility': 1418.9808203257705}
# (03-04) 19:07:29 INFO     [executor.py:149] Received GRPC UpdateModel request
# (03-04) 19:07:29 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:07:29 INFO     [client.py:17] Start to train (CLIENT: 1) ...
# (03-04) 19:07:33 INFO     [client.py:187] Training of (CLIENT: 1) completes, {'clientId': 1, 'moving_loss': 2.0355327106376686, 'trained_size': 600, 'success': True, 'utility': 1486.5715034046652}
# (03-04) 19:07:33 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:07:33 INFO     [client.py:17] Start to train (CLIENT: 2) ...
# (03-04) 19:07:37 INFO     [client.py:187] Training of (CLIENT: 2) completes, {'clientId': 2, 'moving_loss': 2.0312636384942397, 'trained_size': 600, 'success': True, 'utility': 1246.4683177021514}
# (03-04) 19:07:37 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:07:37 INFO     [client.py:17] Start to train (CLIENT: 3) ...
# (03-04) 19:07:42 INFO     [client.py:187] Training of (CLIENT: 3) completes, {'clientId': 3, 'moving_loss': 2.0613371425112135, 'trained_size': 600, 'success': True, 'utility': 1479.4599265851532}
# (03-04) 19:07:42 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:07:42 INFO     [client.py:17] Start to train (CLIENT: 4) ...
# (03-04) 19:07:46 INFO     [client.py:187] Training of (CLIENT: 4) completes, {'clientId': 4, 'moving_loss': 2.0011325796015322, 'trained_size': 600, 'success': True, 'utility': 1289.576032642941}
# (03-04) 19:07:46 INFO     [executor.py:149] Received GRPC UpdateModel request
# (03-04) 19:07:46 INFO     [executor.py:205] Received GRPC Test request
# (03-04) 19:07:51 INFO     [utils_model.py:365] Rank 1: Test set: Average loss: 1.8732, Top-1 Accuracy: 3208.0/10000 (0.3208), Top-5 Accuracy: 0.8372
# (03-04) 19:07:51 INFO     [executor.py:293] After aggregation epoch 30, CumulTime 515.8659, eval_time 4.4936, test_loss 1.8732, test_accuracy 32.08%, test_5_accuracy 83.72%
#
# (03-04) 19:07:51 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:07:51 INFO     [client.py:17] Start to train (CLIENT: 1) ...
# (03-04) 19:07:55 INFO     [client.py:187] Training of (CLIENT: 1) completes, {'clientId': 1, 'moving_loss': 2.0305383274740967, 'trained_size': 600, 'success': True, 'utility': 1462.0001204328105}
# (03-04) 19:07:55 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:07:55 INFO     [client.py:17] Start to train (CLIENT: 2) ...
# (03-04) 19:07:59 INFO     [client.py:187] Training of (CLIENT: 2) completes, {'clientId': 2, 'moving_loss': 1.9336619912446902, 'trained_size': 600, 'success': True, 'utility': 1294.62441163821}
# (03-04) 19:07:59 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:07:59 INFO     [client.py:17] Start to train (CLIENT: 3) ...
# (03-04) 19:08:03 INFO     [client.py:187] Training of (CLIENT: 3) completes, {'clientId': 3, 'moving_loss': 2.0401554220008205, 'trained_size': 600, 'success': True, 'utility': 1583.712187130973}
# (03-04) 19:08:03 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:08:03 INFO     [client.py:17] Start to train (CLIENT: 4) ...
# (03-04) 19:08:07 INFO     [client.py:187] Training of (CLIENT: 4) completes, {'clientId': 4, 'moving_loss': 1.9479474672323027, 'trained_size': 600, 'success': True, 'utility': 1158.5322834130304}
# (03-04) 19:08:07 INFO     [executor.py:149] Received GRPC UpdateModel request
# (03-04) 19:08:07 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:08:07 INFO     [client.py:17] Start to train (CLIENT: 1) ...
# (03-04) 19:08:11 INFO     [client.py:187] Training of (CLIENT: 1) completes, {'clientId': 1, 'moving_loss': 1.9797072131826452, 'trained_size': 600, 'success': True, 'utility': 1235.4327240333362}
# (03-04) 19:08:11 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:08:11 INFO     [client.py:17] Start to train (CLIENT: 2) ...
# (03-04) 19:08:15 INFO     [client.py:187] Training of (CLIENT: 2) completes, {'clientId': 2, 'moving_loss': 1.9243440673473557, 'trained_size': 600, 'success': True, 'utility': 1157.828717293125}
# (03-04) 19:08:15 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:08:15 INFO     [client.py:17] Start to train (CLIENT: 3) ...
# (03-04) 19:08:19 INFO     [client.py:187] Training of (CLIENT: 3) completes, {'clientId': 3, 'moving_loss': 1.8893330867185034, 'trained_size': 600, 'success': True, 'utility': 1385.401167493123}
# (03-04) 19:08:19 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:08:19 INFO     [client.py:17] Start to train (CLIENT: 4) ...
# (03-04) 19:08:23 INFO     [client.py:187] Training of (CLIENT: 4) completes, {'clientId': 4, 'moving_loss': 1.9204015343510246, 'trained_size': 600, 'success': True, 'utility': 1378.105586198975}
# (03-04) 19:08:24 INFO     [executor.py:149] Received GRPC UpdateModel request
# ...
# (03-04) 19:10:30 INFO     [client.py:17] Start to train (CLIENT: 3) ...
# (03-04) 19:10:34 INFO     [client.py:187] Training of (CLIENT: 3) completes, {'clientId': 3, 'moving_loss': 1.823808782631677, 'trained_size': 600, 'success': True, 'utility': 1235.7291308921199}
# (03-04) 19:10:34 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:10:34 INFO     [client.py:17] Start to train (CLIENT: 4) ...
# (03-04) 19:10:38 INFO     [client.py:187] Training of (CLIENT: 4) completes, {'clientId': 4, 'moving_loss': 1.8759606059262108, 'trained_size': 600, 'success': True, 'utility': 1250.8558040972227}
# (03-04) 19:10:39 INFO     [executor.py:149] Received GRPC UpdateModel request
# (03-04) 19:10:39 INFO     [executor.py:205] Received GRPC Test request
# (03-04) 19:10:43 INFO     [utils_model.py:365] Rank 1: Test set: Average loss: 1.7142, Top-1 Accuracy: 3687.0/10000 (0.3687), Top-5 Accuracy: 0.8758
# (03-04) 19:10:43 INFO     [executor.py:293] After aggregation epoch 40, CumulTime 688.2639, eval_time 4.3093, test_loss 1.7142, test_accuracy 36.87%, test_5_accuracy 87.58%
#
# (03-04) 19:10:43 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:10:43 INFO     [client.py:17] Start to train (CLIENT: 1) ...
# (03-04) 19:10:47 INFO     [client.py:187] Training of (CLIENT: 1) completes, {'clientId': 1, 'moving_loss': 1.8480782673562577, 'trained_size': 600, 'success': True, 'utility': 1349.2873695828011}
# (03-04) 19:10:47 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:10:47 INFO     [client.py:17] Start to train (CLIENT: 2) ...
# (03-04) 19:10:51 INFO     [client.py:187] Training of (CLIENT: 2) completes, {'clientId': 2, 'moving_loss': 1.7929372761111932, 'trained_size': 600, 'success': True, 'utility': 1192.4202139105294}
# (03-04) 19:10:51 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:10:51 INFO     [client.py:17] Start to train (CLIENT: 3) ...
# (03-04) 19:10:55 INFO     [client.py:187] Training of (CLIENT: 3) completes, {'clientId': 3, 'moving_loss': 1.7362577744435619, 'trained_size': 600, 'success': True, 'utility': 1151.6871665446422}
# (03-04) 19:10:55 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:10:55 INFO     [client.py:17] Start to train (CLIENT: 4) ...
# (03-04) 19:10:59 INFO     [client.py:187] Training of (CLIENT: 4) completes, {'clientId': 4, 'moving_loss': 1.9925194381759908, 'trained_size': 600, 'success': True, 'utility': 1223.6800289368216}
# (03-04) 19:10:59 INFO     [executor.py:149] Received GRPC UpdateModel request
# (03-04) 19:10:59 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:10:59 INFO     [client.py:17] Start to train (CLIENT: 1) ...
# (03-04) 19:11:03 INFO     [client.py:187] Training of (CLIENT: 1) completes, {'clientId': 1, 'moving_loss': 1.830512400462969, 'trained_size': 600, 'success': True, 'utility': 1497.5041506589423}
# (03-04) 19:11:03 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:11:03 INFO     [client.py:17] Start to train (CLIENT: 2) ...
# (03-04) 19:11:07 INFO     [client.py:187] Training of (CLIENT: 2) completes, {'clientId': 2, 'moving_loss': 1.8349068294544677, 'trained_size': 600, 'success': True, 'utility': 1400.6255865146293}
# (03-04) 19:11:07 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:11:07 INFO     [client.py:17] Start to train (CLIENT: 3) ...
# (03-04) 19:11:11 INFO     [client.py:187] Training of (CLIENT: 3) completes, {'clientId': 3, 'moving_loss': 1.9418907999570807, 'trained_size': 600, 'success': True, 'utility': 1323.0535252059765}
# (03-04) 19:11:11 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:11:11 INFO     [client.py:17] Start to train (CLIENT: 4) ...
# (03-04) 19:11:15 INFO     [client.py:187] Training of (CLIENT: 4) completes, {'clientId': 4, 'moving_loss': 1.8719995287896458, 'trained_size': 600, 'success': True, 'utility': 1248.070292408145}
# (03-04) 19:11:15 INFO     [executor.py:149] Received GRPC UpdateModel request
# (03-04) 19:11:15 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:11:15 INFO     [client.py:17] Start to train (CLIENT: 1) ...
# (03-04) 19:11:19 INFO     [client.py:187] Training of (CLIENT: 1) completes, {'clientId': 1, 'moving_loss': 1.8989385305273616, 'trained_size': 600, 'success': True, 'utility': 1252.9275700778478}
# (03-04) 19:11:19 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:11:19 INFO     [client.py:17] Start to train (CLIENT: 2) ...
# (03-04) 19:11:23 INFO     [client.py:187] Training of (CLIENT: 2) completes, {'clientId': 2, 'moving_loss': 1.775787281583479, 'trained_size': 600, 'success': True, 'utility': 1148.2196153196924}
# (03-04) 19:11:23 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:11:23 INFO     [client.py:17] Start to train (CLIENT: 3) ...
# (03-04) 19:11:27 INFO     [client.py:187] Training of (CLIENT: 3) completes, {'clientId': 3, 'moving_loss': 1.8291749204061216, 'trained_size': 600, 'success': True, 'utility': 1573.2588188051598}
# (03-04) 19:11:27 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:11:27 INFO     [client.py:17] Start to train (CLIENT: 4) ...
# (03-04) 19:11:31 INFO     [client.py:187] Training of (CLIENT: 4) completes, {'clientId': 4, 'moving_loss': 1.817014992881873, 'trained_size': 600, 'success': True, 'utility': 1343.8027938668965}
# (03-04) 19:11:32 INFO     [executor.py:149] Received GRPC UpdateModel request
# (03-04) 19:11:32 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:11:32 INFO     [client.py:17] Start to train (CLIENT: 1) ...
# (03-04) 19:11:36 INFO     [client.py:187] Training of (CLIENT: 1) completes, {'clientId': 1, 'moving_loss': 1.7653575749297026, 'trained_size': 600, 'success': True, 'utility': 1071.7437489588135}
# (03-04) 19:11:36 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:11:36 INFO     [client.py:17] Start to train (CLIENT: 2) ...
# (03-04) 19:11:40 INFO     [client.py:187] Training of (CLIENT: 2) completes, {'clientId': 2, 'moving_loss': 1.7762739099131988, 'trained_size': 600, 'success': True, 'utility': 1125.4640787204673}
# (03-04) 19:11:40 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:11:40 INFO     [client.py:17] Start to train (CLIENT: 3) ...
# (03-04) 19:11:44 INFO     [client.py:187] Training of (CLIENT: 3) completes, {'clientId': 3, 'moving_loss': 1.847365836964642, 'trained_size': 600, 'success': True, 'utility': 1311.266167072203}
# (03-04) 19:11:44 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:11:44 INFO     [client.py:17] Start to train (CLIENT: 4) ...
# (03-04) 19:11:48 INFO     [client.py:187] Training of (CLIENT: 4) completes, {'clientId': 4, 'moving_loss': 1.835720740653963, 'trained_size': 600, 'success': True, 'utility': 1205.3348487562137}
# (03-04) 19:11:48 INFO     [executor.py:149] Received GRPC UpdateModel request
# (03-04) 19:11:48 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:11:48 INFO     [client.py:17] Start to train (CLIENT: 1) ...
# (03-04) 19:11:52 INFO     [client.py:187] Training of (CLIENT: 1) completes, {'clientId': 1, 'moving_loss': 1.7371126621593311, 'trained_size': 600, 'success': True, 'utility': 1077.966875395407}
# (03-04) 19:11:52 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:11:52 INFO     [client.py:17] Start to train (CLIENT: 2) ...
# (03-04) 19:11:56 INFO     [client.py:187] Training of (CLIENT: 2) completes, {'clientId': 2, 'moving_loss': 1.8277168456818187, 'trained_size': 600, 'success': True, 'utility': 980.834935755168}
# (03-04) 19:11:56 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:11:56 INFO     [client.py:17] Start to train (CLIENT: 3) ...
# (03-04) 19:12:00 INFO     [client.py:187] Training of (CLIENT: 3) completes, {'clientId': 3, 'moving_loss': 1.7426662545213896, 'trained_size': 600, 'success': True, 'utility': 1190.0903242930522}
# (03-04) 19:12:00 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:12:00 INFO     [client.py:17] Start to train (CLIENT: 4) ...
# (03-04) 19:12:04 INFO     [client.py:187] Training of (CLIENT: 4) completes, {'clientId': 4, 'moving_loss': 1.7995705533812911, 'trained_size': 600, 'success': True, 'utility': 1096.5121526956664}
# (03-04) 19:12:04 INFO     [executor.py:149] Received GRPC UpdateModel request
# (03-04) 19:12:04 INFO     [executor.py:205] Received GRPC Test request
# (03-04) 19:12:09 INFO     [utils_model.py:365] Rank 1: Test set: Average loss: 1.7289, Top-1 Accuracy: 3732.0/10000 (0.3732), Top-5 Accuracy: 0.8726
# (03-04) 19:12:09 INFO     [executor.py:293] After aggregation epoch 45, CumulTime 773.9432, eval_time 4.2966, test_loss 1.7289, test_accuracy 37.32%, test_5_accuracy 87.26%
#
# (03-04) 19:12:09 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:12:09 INFO     [client.py:17] Start to train (CLIENT: 1) ...
# (03-04) 19:12:13 INFO     [client.py:187] Training of (CLIENT: 1) completes, {'clientId': 1, 'moving_loss': 1.8155192238236744, 'trained_size': 600, 'success': True, 'utility': 1223.4512171144706}
# (03-04) 19:12:13 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:12:13 INFO     [client.py:17] Start to train (CLIENT: 2) ...
# (03-04) 19:12:17 INFO     [client.py:187] Training of (CLIENT: 2) completes, {'clientId': 2, 'moving_loss': 1.6942830882404383, 'trained_size': 600, 'success': True, 'utility': 1220.0262536952941}
# (03-04) 19:12:17 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:12:17 INFO     [client.py:17] Start to train (CLIENT: 3) ...
# (03-04) 19:12:21 INFO     [client.py:187] Training of (CLIENT: 3) completes, {'clientId': 3, 'moving_loss': 1.758519491861119, 'trained_size': 600, 'success': True, 'utility': 1198.2531382610441}
# (03-04) 19:12:21 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:12:21 INFO     [client.py:17] Start to train (CLIENT: 4) ...
# (03-04) 19:12:25 INFO     [client.py:187] Training of (CLIENT: 4) completes, {'clientId': 4, 'moving_loss': 1.7202173000410665, 'trained_size': 600, 'success': True, 'utility': 1110.2569567005607}
# (03-04) 19:12:25 INFO     [executor.py:149] Received GRPC UpdateModel request
# (03-04) 19:12:25 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:12:25 INFO     [client.py:17] Start to train (CLIENT: 1) ...
# (03-04) 19:12:29 INFO     [client.py:187] Training of (CLIENT: 1) completes, {'clientId': 1, 'moving_loss': 1.7759415210484475, 'trained_size': 600, 'success': True, 'utility': 1210.253651626164}
# (03-04) 19:12:29 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:12:29 INFO     [client.py:17] Start to train (CLIENT: 2) ...
# (03-04) 19:12:33 INFO     [client.py:187] Training of (CLIENT: 2) completes, {'clientId': 2, 'moving_loss': 1.747010003322145, 'trained_size': 600, 'success': True, 'utility': 1103.5466093429604}
# (03-04) 19:12:33 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:12:33 INFO     [client.py:17] Start to train (CLIENT: 3) ...
# (03-04) 19:12:37 INFO     [client.py:187] Training of (CLIENT: 3) completes, {'clientId': 3, 'moving_loss': 1.878420482771366, 'trained_size': 600, 'success': True, 'utility': 1268.764633241904}
# (03-04) 19:12:37 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:12:37 INFO     [client.py:17] Start to train (CLIENT: 4) ...
# (03-04) 19:12:41 INFO     [client.py:187] Training of (CLIENT: 4) completes, {'clientId': 4, 'moving_loss': 1.7935136843749835, 'trained_size': 600, 'success': True, 'utility': 1320.5959884231283}
# (03-04) 19:12:41 INFO     [executor.py:149] Received GRPC UpdateModel request
# (03-04) 19:12:42 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:12:42 INFO     [client.py:17] Start to train (CLIENT: 1) ...
# (03-04) 19:12:45 INFO     [client.py:187] Training of (CLIENT: 1) completes, {'clientId': 1, 'moving_loss': 1.8927883399908343, 'trained_size': 600, 'success': True, 'utility': 1241.9022626200242}
# (03-04) 19:12:45 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:12:45 INFO     [client.py:17] Start to train (CLIENT: 2) ...
# (03-04) 19:12:49 INFO     [client.py:187] Training of (CLIENT: 2) completes, {'clientId': 2, 'moving_loss': 1.7426845588770072, 'trained_size': 600, 'success': True, 'utility': 1203.1526005188289}
# (03-04) 19:12:49 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:12:49 INFO     [client.py:17] Start to train (CLIENT: 3) ...
# (03-04) 19:12:53 INFO     [client.py:187] Training of (CLIENT: 3) completes, {'clientId': 3, 'moving_loss': 1.7940250114440794, 'trained_size': 600, 'success': True, 'utility': 1373.3160368345784}
# (03-04) 19:12:53 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:12:53 INFO     [client.py:17] Start to train (CLIENT: 4) ...
# (03-04) 19:12:57 INFO     [client.py:187] Training of (CLIENT: 4) completes, {'clientId': 4, 'moving_loss': 1.692213951236378, 'trained_size': 600, 'success': True, 'utility': 1060.3130446814387}
# (03-04) 19:12:57 INFO     [executor.py:149] Received GRPC UpdateModel request
# (03-04) 19:12:58 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:12:58 INFO     [client.py:17] Start to train (CLIENT: 1) ...
# (03-04) 19:13:02 INFO     [client.py:187] Training of (CLIENT: 1) completes, {'clientId': 1, 'moving_loss': 1.6825047396255601, 'trained_size': 600, 'success': True, 'utility': 1056.03719964548}
# (03-04) 19:13:02 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:13:02 INFO     [client.py:17] Start to train (CLIENT: 2) ...
# (03-04) 19:13:06 INFO     [client.py:187] Training of (CLIENT: 2) completes, {'clientId': 2, 'moving_loss': 1.8255833605761063, 'trained_size': 600, 'success': True, 'utility': 1203.3196667939758}
# (03-04) 19:13:06 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:13:06 INFO     [client.py:17] Start to train (CLIENT: 3) ...
# (03-04) 19:13:10 INFO     [client.py:187] Training of (CLIENT: 3) completes, {'clientId': 3, 'moving_loss': 1.8659166042251347, 'trained_size': 600, 'success': True, 'utility': 1360.2930216675932}
# (03-04) 19:13:10 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:13:10 INFO     [client.py:17] Start to train (CLIENT: 4) ...
# (03-04) 19:13:14 INFO     [client.py:187] Training of (CLIENT: 4) completes, {'clientId': 4, 'moving_loss': 1.7575865862914926, 'trained_size': 600, 'success': True, 'utility': 1134.9229748027444}
# (03-04) 19:13:14 INFO     [executor.py:149] Received GRPC UpdateModel request
# (03-04) 19:13:14 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:13:14 INFO     [client.py:17] Start to train (CLIENT: 1) ...
# (03-04) 19:13:18 INFO     [client.py:187] Training of (CLIENT: 1) completes, {'clientId': 1, 'moving_loss': 1.7481981175983927, 'trained_size': 600, 'success': True, 'utility': 1201.7558842457438}
# (03-04) 19:13:18 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:13:18 INFO     [client.py:17] Start to train (CLIENT: 2) ...
# (03-04) 19:13:22 INFO     [client.py:187] Training of (CLIENT: 2) completes, {'clientId': 2, 'moving_loss': 1.763054232942623, 'trained_size': 600, 'success': True, 'utility': 1303.9145071883454}
# (03-04) 19:13:22 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:13:22 INFO     [client.py:17] Start to train (CLIENT: 3) ...
# (03-04) 19:13:26 INFO     [client.py:187] Training of (CLIENT: 3) completes, {'clientId': 3, 'moving_loss': 1.9435487088980432, 'trained_size': 600, 'success': True, 'utility': 1465.3837427969681}
# (03-04) 19:13:26 INFO     [executor.py:167] Received GRPC Train request
# (03-04) 19:13:26 INFO     [client.py:17] Start to train (CLIENT: 4) ...
# (03-04) 19:13:30 INFO     [client.py:187] Training of (CLIENT: 4) completes, {'clientId': 4, 'moving_loss': 1.8471025003468946, 'trained_size': 600, 'success': True, 'utility': 1383.5083075734728}
# (03-04) 19:13:30 INFO     [executor.py:186] Received GRPC Stop request
# (03-04) 19:13:31 INFO     [executor.py:306] Terminating (Executor 1) ...
