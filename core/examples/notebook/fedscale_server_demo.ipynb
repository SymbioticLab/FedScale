# %% [markdown]
# # Federated Learning for Image Classification using Fedscale
#
# FedScale, a diverse set of challenging and realistic benchmark datasets to facilitate scalable, comprehensive, and reproducible federated learning (FL) research. FedScale datasets are large-scale, encompassing a diverse range of important FL tasks, such as image classification, object detection, language modeling, speech recognition, and reinforcement learning. For each dataset, we provide a unified evaluation protocol using realistic data splits and evaluation metrics. To meet the pressing need for reproducing realistic FL at scale, we have also built an efficient evaluation platform, FedScale Automated Runtime (FAR), to simplify and standardize the process of FL experimental setup and model evaluation. Our evaluation platform provides flexible APIs to implement new FL algorithms and include new execution backends with minimal developer efforts.

# %%
import sys, os
sys.path.insert(1, os.path.join(sys.path[0], './FedScale/core/'))
from FedScale.core.client import Client
from FedScale.core.aggregator import Aggregator
from FedScale.core.fl_client_libs import args
Demo_Aggregator = Aggregator(args)
Demo_Aggregator.run()
# Out:
# (03-03) 20:36:04 INFO     [aggregator.py:21] Job args Namespace(adam_epsilon=1e-08, backbone='./resnet50.pth', backend='gloo', base_port=10001, batch_size=30, bidirectional=True, blacklist_max_len=0.3, blacklist_rounds=-1, block_size=64, cfg_file='./utils/rcnn/cfgs/res101.yml', clf_block_size=32, clip_bound=0.9, clock_factor=1.1624548736462095, conf_path='~/dataset/', cuda_device=None, cut_off_util=0.05, data_cache='', data_dir='~/cifar10/', data_map_file=None, data_set='cifar10', decay_epoch=10, decay_factor=0.98, device_avail_file=None, device_conf_file='/tmp/client.cfg', dump_epoch=10000000000.0, embedding_file='glove.840B.300d.txt', epochs=50, epsilon=0.9, eval_interval=5, executor_configs='127.0.0.1:[1]', exploration_alpha=0.3, exploration_decay=0.98, exploration_factor=0.9, exploration_min=0.3, filter_less=32, filter_more=1000000000000000.0, finetune=False, gamma=0.9, gradient_policy=None, hidden_layers=7, hidden_size=256, input_dim=0, job_name='demo_job', labels_path='labels.json', learning_rate=0.05, line_by_line=False, local_steps=20, log_path='./', loss_decay=0.2, malicious_factor=1000000000000000.0, manager_port=9005, memory_capacity=2000, min_learning_rate=5e-05, mlm=False, mlm_probability=0.15, model='shufflenet_v2_x2_0', model_size=65536, n_actions=2, n_states=4, noise_dir=None, noise_factor=0.1, noise_max=0.5, noise_min=0.0, noise_prob=0.4, num_class=10, num_classes=35, num_executors=1, num_loaders=2, output_dim=0, overcommitment=1.3, overwrite_cache=False, pacer_delta=5, pacer_step=20, proxy_mu=0.1, ps_ip='127.0.0.1', ps_port='29501', rnn_type='lstm', round_penalty=2.0, round_threshold=30, sample_mode='random', sample_rate=16000, sample_seed=233, sample_window=5.0, spec_augment=False, speed_volume_perturb=False, target_replace_iter=15, task='cv', test_bsz=128, test_manifest='data/test_manifest.csv', test_output_dir='./logs/server', test_ratio=1.0, test_size_file='', this_rank=1, time_stamp='logs', total_worker=4, train_manifest='data/train_manifest.csv', train_size_file='', train_uniform=False, upload_epoch=20, use_cuda=False, vocab_tag_size=500, vocab_token_size=10000, weight_decay=0, window='hamming', window_size=0.02, window_stride=0.01, yogi_beta=0.9, yogi_beta2=0.99, yogi_eta=0.003, yogi_tau=1e-08)
# (03-03) 20:36:04 INFO     [aggregator.py:107] Initiating control plane communication ... 127.0.0.1:[1]
# (03-03) 20:36:04 INFO     [fllibs.py:84] Initializing the model ...
# (03-03) 20:36:05 INFO     [aggregator.py:439] Start monitoring events ...
# (03-03) 20:36:25 INFO     [channelcontext.py:38] %%%%%%%%%% Opening grpc connection to 127.0.0.1:10002 %%%%%%%%%%
# (03-03) 20:36:25 INFO     [aggregator.py:155] Received executor 1 information, 1/1
# (03-03) 20:36:25 INFO     [aggregator.py:163] Loading 4 client traces ...
# (03-03) 20:36:25 INFO     [aggregator.py:174] Info of all feasible clients {'total_feasible_clients': 4, 'total_num_samples': 50000}
# (03-03) 20:36:25 INFO     [aggregator.py:292] Wall clock: 0 s, Epoch: 1, Planned participants: 0, Succeed participants: 0, Training loss: 0.0
# (03-03) 20:36:25 INFO     [client_manager.py:163] Wall clock time: 0, 4 clients online, 0 clients offline
# (03-03) 20:36:25 INFO     [aggregator.py:308] Selected participants to run: [1, 2, 3, 4]:
# {1: {'computation': 1.8, 'communication': 339809.15625}, 2: {'computation': 1.8, 'communication': 339809.15625}, 3: {'computation': 1.8, 'communication': 339809.15625}, 4: {'computation': 1.8, 'communication': 339809.15625}}
# (03-03) 20:36:25 INFO     [aggregator.py:457] Have received all executor information
# (03-03) 20:36:38 INFO     [aggregator.py:292] Wall clock: 339811 s, Epoch: 2, Planned participants: 4, Succeed participants: 4, Training loss: 6.363428840824658
# (03-03) 20:36:38 INFO     [client_manager.py:163] Wall clock time: 339811, 4 clients online, 0 clients offline
# (03-03) 20:36:38 INFO     [aggregator.py:308] Selected participants to run: [1, 2, 3, 4]:
# {1: {'computation': 1.8, 'communication': 339809.15625}, 2: {'computation': 1.8, 'communication': 339809.15625}, 3: {'computation': 1.8, 'communication': 339809.15625}, 4: {'computation': 1.8, 'communication': 339809.15625}}
# (03-03) 20:36:54 INFO     [aggregator.py:292] Wall clock: 679622 s, Epoch: 3, Planned participants: 4, Succeed participants: 4, Training loss: 6.050180173685863
# (03-03) 20:36:54 INFO     [client_manager.py:163] Wall clock time: 679622, 4 clients online, 0 clients offline
# (03-03) 20:36:54 INFO     [aggregator.py:308] Selected participants to run: [1, 2, 3, 4]:
# {1: {'computation': 1.8, 'communication': 339809.15625}, 2: {'computation': 1.8, 'communication': 339809.15625}, 3: {'computation': 1.8, 'communication': 339809.15625}, 4: {'computation': 1.8, 'communication': 339809.15625}}
# (03-03) 20:37:10 INFO     [aggregator.py:292] Wall clock: 1019433 s, Epoch: 4, Planned participants: 4, Succeed participants: 4, Training loss: 6.114354893190519
# (03-03) 20:37:10 INFO     [client_manager.py:163] Wall clock time: 1019433, 4 clients online, 0 clients offline
# (03-03) 20:37:10 INFO     [aggregator.py:308] Selected participants to run: [1, 2, 3, 4]:
# {1: {'computation': 1.8, 'communication': 339809.15625}, 2: {'computation': 1.8, 'communication': 339809.15625}, 3: {'computation': 1.8, 'communication': 339809.15625}, 4: {'computation': 1.8, 'communication': 339809.15625}}
# (03-03) 20:37:27 INFO     [aggregator.py:292] Wall clock: 1359244 s, Epoch: 5, Planned participants: 4, Succeed participants: 4, Training loss: 6.022236353738536
# (03-03) 20:37:27 INFO     [client_manager.py:163] Wall clock time: 1359244, 4 clients online, 0 clients offline
# (03-03) 20:37:27 INFO     [aggregator.py:308] Selected participants to run: [1, 2, 3, 4]:
# {1: {'computation': 1.8, 'communication': 339809.15625}, 2: {'computation': 1.8, 'communication': 339809.15625}, 3: {'computation': 1.8, 'communication': 339809.15625}, 4: {'computation': 1.8, 'communication': 339809.15625}}
# (03-03) 20:37:32 INFO     [aggregator.py:376] FL Testing in epoch: 5, virtual_clock: 1359243.825, top_1: 10.13 %, top_5: 49.67 %, test loss: 902.2027, test len: 10000
# (03-03) 20:37:48 INFO     [aggregator.py:292] Wall clock: 1699055 s, Epoch: 6, Planned participants: 4, Succeed participants: 4, Training loss: 5.747627650179679
# (03-03) 20:37:48 INFO     [client_manager.py:163] Wall clock time: 1699055, 4 clients online, 0 clients offline
# (03-03) 20:37:48 INFO     [aggregator.py:308] Selected participants to run: [1, 2, 3, 4]:
# {1: {'computation': 1.8, 'communication': 339809.15625}, 2: {'computation': 1.8, 'communication': 339809.15625}, 3: {'computation': 1.8, 'communication': 339809.15625}, 4: {'computation': 1.8, 'communication': 339809.15625}}
# (03-03) 20:38:04 INFO     [aggregator.py:292] Wall clock: 2038866 s, Epoch: 7, Planned participants: 4, Succeed participants: 4, Training loss: 5.380593921039341
# (03-03) 20:38:04 INFO     [client_manager.py:163] Wall clock time: 2038866, 4 clients online, 0 clients offline
# (03-03) 20:38:04 INFO     [aggregator.py:308] Selected participants to run: [1, 2, 3, 4]:
# {1: {'computation': 1.8, 'communication': 339809.15625}, 2: {'computation': 1.8, 'communication': 339809.15625}, 3: {'computation': 1.8, 'communication': 339809.15625}, 4: {'computation': 1.8, 'communication': 339809.15625}}
# (03-03) 20:38:20 INFO     [aggregator.py:292] Wall clock: 2378677 s, Epoch: 8, Planned participants: 4, Succeed participants: 4, Training loss: 5.018207968597824
# (03-03) 20:38:20 INFO     [client_manager.py:163] Wall clock time: 2378677, 4 clients online, 0 clients offline
# (03-03) 20:38:20 INFO     [aggregator.py:308] Selected participants to run: [1, 2, 3, 4]:
# {1: {'computation': 1.8, 'communication': 339809.15625}, 2: {'computation': 1.8, 'communication': 339809.15625}, 3: {'computation': 1.8, 'communication': 339809.15625}, 4: {'computation': 1.8, 'communication': 339809.15625}}
# (03-03) 20:38:36 INFO     [aggregator.py:292] Wall clock: 2718488 s, Epoch: 9, Planned participants: 4, Succeed participants: 4, Training loss: 4.718980452667677
# (03-03) 20:38:36 INFO     [client_manager.py:163] Wall clock time: 2718488, 4 clients online, 0 clients offline
# (03-03) 20:38:36 INFO     [aggregator.py:308] Selected participants to run: [1, 2, 3, 4]:
# {1: {'computation': 1.8, 'communication': 339809.15625}, 2: {'computation': 1.8, 'communication': 339809.15625}, 3: {'computation': 1.8, 'communication': 339809.15625}, 4: {'computation': 1.8, 'communication': 339809.15625}}
# (03-03) 20:38:52 INFO     [aggregator.py:292] Wall clock: 3058299 s, Epoch: 10, Planned participants: 4, Succeed participants: 4, Training loss: 4.463670654565373
# (03-03) 20:38:52 INFO     [client_manager.py:163] Wall clock time: 3058299, 4 clients online, 0 clients offline
# (03-03) 20:38:52 INFO     [aggregator.py:308] Selected participants to run: [1, 2, 3, 4]:
# {1: {'computation': 1.8, 'communication': 339809.15625}, 2: {'computation': 1.8, 'communication': 339809.15625}, 3: {'computation': 1.8, 'communication': 339809.15625}, 4: {'computation': 1.8, 'communication': 339809.15625}}
# (03-03) 20:38:57 INFO     [aggregator.py:376] FL Testing in epoch: 10, virtual_clock: 3058298.6062499997, top_1: 16.35 %, top_5: 65.38 %, test loss: 2.3310, test len: 10000
# (03-03) 20:39:13 INFO     [aggregator.py:292] Wall clock: 3398110 s, Epoch: 11, Planned participants: 4, Succeed participants: 4, Training loss: 4.252917483430275
# (03-03) 20:39:13 INFO     [client_manager.py:163] Wall clock time: 3398110, 4 clients online, 0 clients offline
# (03-03) 20:39:13 INFO     [aggregator.py:308] Selected participants to run: [1, 2, 3, 4]:
# {1: {'computation': 1.8, 'communication': 339809.15625}, 2: {'computation': 1.8, 'communication': 339809.15625}, 3: {'computation': 1.8, 'communication': 339809.15625}, 4: {'computation': 1.8, 'communication': 339809.15625}}
# (03-03) 20:39:30 INFO     [aggregator.py:292] Wall clock: 3737921 s, Epoch: 12, Planned participants: 4, Succeed participants: 4, Training loss: 4.077245229859065
# (03-03) 20:39:30 INFO     [client_manager.py:163] Wall clock time: 3737921, 4 clients online, 0 clients offline
# (03-03) 20:39:30 INFO     [aggregator.py:308] Selected participants to run: [1, 2, 3, 4]:
# {1: {'computation': 1.8, 'communication': 339809.15625}, 2: {'computation': 1.8, 'communication': 339809.15625}, 3: {'computation': 1.8, 'communication': 339809.15625}, 4: {'computation': 1.8, 'communication': 339809.15625}}
# (03-03) 20:39:46 INFO     [aggregator.py:292] Wall clock: 4077731 s, Epoch: 13, Planned participants: 4, Succeed participants: 4, Training loss: 3.924446917903822
# (03-03) 20:39:46 INFO     [client_manager.py:163] Wall clock time: 4077731, 4 clients online, 0 clients offline
# (03-03) 20:39:46 INFO     [aggregator.py:308] Selected participants to run: [1, 2, 3, 4]:
# {1: {'computation': 1.8, 'communication': 339809.15625}, 2: {'computation': 1.8, 'communication': 339809.15625}, 3: {'computation': 1.8, 'communication': 339809.15625}, 4: {'computation': 1.8, 'communication': 339809.15625}}
# (03-03) 20:40:03 INFO     [aggregator.py:292] Wall clock: 4417542 s, Epoch: 14, Planned participants: 4, Succeed participants: 4, Training loss: 3.7951296094941336
# (03-03) 20:40:03 INFO     [client_manager.py:163] Wall clock time: 4417542, 4 clients online, 0 clients offline
# (03-03) 20:40:03 INFO     [aggregator.py:308] Selected participants to run: [1, 2, 3, 4]:
# {1: {'computation': 1.8, 'communication': 339809.15625}, 2: {'computation': 1.8, 'communication': 339809.15625}, 3: {'computation': 1.8, 'communication': 339809.15625}, 4: {'computation': 1.8, 'communication': 339809.15625}}
# (03-03) 20:40:19 INFO     [aggregator.py:292] Wall clock: 4757353 s, Epoch: 15, Planned participants: 4, Succeed participants: 4, Training loss: 3.6832029151664742
# (03-03) 20:40:19 INFO     [client_manager.py:163] Wall clock time: 4757353, 4 clients online, 0 clients offline
# (03-03) 20:40:19 INFO     [aggregator.py:308] Selected participants to run: [1, 2, 3, 4]:
# {1: {'computation': 1.8, 'communication': 339809.15625}, 2: {'computation': 1.8, 'communication': 339809.15625}, 3: {'computation': 1.8, 'communication': 339809.15625}, 4: {'computation': 1.8, 'communication': 339809.15625}}
# (03-03) 20:40:24 INFO     [aggregator.py:376] FL Testing in epoch: 15, virtual_clock: 4757353.387499999, top_1: 22.12 %, top_5: 72.93 %, test loss: 2.1425, test len: 10000
# (03-03) 20:40:40 INFO     [aggregator.py:292] Wall clock: 5097164 s, Epoch: 16, Planned participants: 4, Succeed participants: 4, Training loss: 3.582622703655745
# (03-03) 20:40:40 INFO     [client_manager.py:163] Wall clock time: 5097164, 4 clients online, 0 clients offline
# (03-03) 20:40:40 INFO     [aggregator.py:308] Selected participants to run: [1, 2, 3, 4]:
# {1: {'computation': 1.8, 'communication': 339809.15625}, 2: {'computation': 1.8, 'communication': 339809.15625}, 3: {'computation': 1.8, 'communication': 339809.15625}, 4: {'computation': 1.8, 'communication': 339809.15625}}
# (03-03) 20:40:57 INFO     [aggregator.py:292] Wall clock: 5436975 s, Epoch: 17, Planned participants: 4, Succeed participants: 4, Training loss: 3.4972757549553646
# (03-03) 20:40:57 INFO     [client_manager.py:163] Wall clock time: 5436975, 4 clients online, 0 clients offline
# (03-03) 20:40:57 INFO     [aggregator.py:308] Selected participants to run: [1, 2, 3, 4]:
# {1: {'computation': 1.8, 'communication': 339809.15625}, 2: {'computation': 1.8, 'communication': 339809.15625}, 3: {'computation': 1.8, 'communication': 339809.15625}, 4: {'computation': 1.8, 'communication': 339809.15625}}
# (03-03) 20:41:13 INFO     [aggregator.py:292] Wall clock: 5776786 s, Epoch: 18, Planned participants: 4, Succeed participants: 4, Training loss: 3.422557139177359
# (03-03) 20:41:13 INFO     [client_manager.py:163] Wall clock time: 5776786, 4 clients online, 0 clients offline
# (03-03) 20:41:13 INFO     [aggregator.py:308] Selected participants to run: [1, 2, 3, 4]:
# {1: {'computation': 1.8, 'communication': 339809.15625}, 2: {'computation': 1.8, 'communication': 339809.15625}, 3: {'computation': 1.8, 'communication': 339809.15625}, 4: {'computation': 1.8, 'communication': 339809.15625}}
# (03-03) 20:41:30 INFO     [aggregator.py:292] Wall clock: 6116597 s, Epoch: 19, Planned participants: 4, Succeed participants: 4, Training loss: 3.353506672056696
# (03-03) 20:41:30 INFO     [client_manager.py:163] Wall clock time: 6116597, 4 clients online, 0 clients offline
# (03-03) 20:41:30 INFO     [aggregator.py:308] Selected participants to run: [1, 2, 3, 4]:
# {1: {'computation': 1.8, 'communication': 339809.15625}, 2: {'computation': 1.8, 'communication': 339809.15625}, 3: {'computation': 1.8, 'communication': 339809.15625}, 4: {'computation': 1.8, 'communication': 339809.15625}}
# (03-03) 20:41:46 INFO     [aggregator.py:292] Wall clock: 6456408 s, Epoch: 20, Planned participants: 4, Succeed participants: 4, Training loss: 3.2920484123893625
# (03-03) 20:41:46 INFO     [client_manager.py:163] Wall clock time: 6456408, 4 clients online, 0 clients offline
# (03-03) 20:41:46 INFO     [aggregator.py:308] Selected participants to run: [1, 2, 3, 4]:
# {1: {'computation': 1.8, 'communication': 339809.15625}, 2: {'computation': 1.8, 'communication': 339809.15625}, 3: {'computation': 1.8, 'communication': 339809.15625}, 4: {'computation': 1.8, 'communication': 339809.15625}}
# (03-03) 20:41:51 INFO     [aggregator.py:376] FL Testing in epoch: 20, virtual_clock: 6456408.168749998, top_1: 23.54 %, top_5: 72.81 %, test loss: 2.1878, test len: 10000
# (03-03) 20:42:07 INFO     [aggregator.py:292] Wall clock: 6796219 s, Epoch: 21, Planned participants: 4, Succeed participants: 4, Training loss: 3.234489626131537
# (03-03) 20:42:07 INFO     [client_manager.py:163] Wall clock time: 6796219, 4 clients online, 0 clients offline
# (03-03) 20:42:07 INFO     [aggregator.py:308] Selected participants to run: [1, 2, 3, 4]:
# {1: {'computation': 1.8, 'communication': 339809.15625}, 2: {'computation': 1.8, 'communication': 339809.15625}, 3: {'computation': 1.8, 'communication': 339809.15625}, 4: {'computation': 1.8, 'communication': 339809.15625}}
# (03-03) 20:42:23 INFO     [aggregator.py:292] Wall clock: 7136030 s, Epoch: 22, Planned participants: 4, Succeed participants: 4, Training loss: 3.1816059564514503
# (03-03) 20:42:23 INFO     [client_manager.py:163] Wall clock time: 7136030, 4 clients online, 0 clients offline
# (03-03) 20:42:23 INFO     [aggregator.py:308] Selected participants to run: [1, 2, 3, 4]:
# {1: {'computation': 1.8, 'communication': 339809.15625}, 2: {'computation': 1.8, 'communication': 339809.15625}, 3: {'computation': 1.8, 'communication': 339809.15625}, 4: {'computation': 1.8, 'communication': 339809.15625}}
# (03-03) 20:42:40 INFO     [aggregator.py:292] Wall clock: 7475841 s, Epoch: 23, Planned participants: 4, Succeed participants: 4, Training loss: 3.1340829096585865
# (03-03) 20:42:40 INFO     [client_manager.py:163] Wall clock time: 7475841, 4 clients online, 0 clients offline
# (03-03) 20:42:40 INFO     [aggregator.py:308] Selected participants to run: [1, 2, 3, 4]:
# {1: {'computation': 1.8, 'communication': 339809.15625}, 2: {'computation': 1.8, 'communication': 339809.15625}, 3: {'computation': 1.8, 'communication': 339809.15625}, 4: {'computation': 1.8, 'communication': 339809.15625}}
# (03-03) 20:42:56 INFO     [aggregator.py:292] Wall clock: 7815652 s, Epoch: 24, Planned participants: 4, Succeed participants: 4, Training loss: 3.089161296527864
# (03-03) 20:42:56 INFO     [client_manager.py:163] Wall clock time: 7815652, 4 clients online, 0 clients offline
# (03-03) 20:42:56 INFO     [aggregator.py:308] Selected participants to run: [1, 2, 3, 4]:
# {1: {'computation': 1.8, 'communication': 339809.15625}, 2: {'computation': 1.8, 'communication': 339809.15625}, 3: {'computation': 1.8, 'communication': 339809.15625}, 4: {'computation': 1.8, 'communication': 339809.15625}}
# (03-03) 20:43:13 INFO     [aggregator.py:292] Wall clock: 8155463 s, Epoch: 25, Planned participants: 4, Succeed participants: 4, Training loss: 3.049245915350619
# (03-03) 20:43:13 INFO     [client_manager.py:163] Wall clock time: 8155463, 4 clients online, 0 clients offline
# (03-03) 20:43:13 INFO     [aggregator.py:308] Selected participants to run: [1, 2, 3, 4]:
# {1: {'computation': 1.8, 'communication': 339809.15625}, 2: {'computation': 1.8, 'communication': 339809.15625}, 3: {'computation': 1.8, 'communication': 339809.15625}, 4: {'computation': 1.8, 'communication': 339809.15625}}
# (03-03) 20:43:17 INFO     [aggregator.py:376] FL Testing in epoch: 25, virtual_clock: 8155462.949999997, top_1: 25.89 %, top_5: 77.83 %, test loss: 2.0797, test len: 10000
# (03-03) 20:43:33 INFO     [aggregator.py:292] Wall clock: 8495274 s, Epoch: 26, Planned participants: 4, Succeed participants: 4, Training loss: 3.0115864439231483
# (03-03) 20:43:33 INFO     [client_manager.py:163] Wall clock time: 8495274, 4 clients online, 0 clients offline
# (03-03) 20:43:33 INFO     [aggregator.py:308] Selected participants to run: [1, 2, 3, 4]:
# {1: {'computation': 1.8, 'communication': 339809.15625}, 2: {'computation': 1.8, 'communication': 339809.15625}, 3: {'computation': 1.8, 'communication': 339809.15625}, 4: {'computation': 1.8, 'communication': 339809.15625}}
# (03-03) 20:43:50 INFO     [aggregator.py:292] Wall clock: 8835085 s, Epoch: 27, Planned participants: 4, Succeed participants: 4, Training loss: 2.9761052159926082
# (03-03) 20:43:50 INFO     [client_manager.py:163] Wall clock time: 8835085, 4 clients online, 0 clients offline
# (03-03) 20:43:50 INFO     [aggregator.py:308] Selected participants to run: [1, 2, 3, 4]:
# {1: {'computation': 1.8, 'communication': 339809.15625}, 2: {'computation': 1.8, 'communication': 339809.15625}, 3: {'computation': 1.8, 'communication': 339809.15625}, 4: {'computation': 1.8, 'communication': 339809.15625}}
# (03-03) 20:44:06 INFO     [aggregator.py:292] Wall clock: 9174896 s, Epoch: 28, Planned participants: 4, Succeed participants: 4, Training loss: 2.940973116879402
# (03-03) 20:44:06 INFO     [client_manager.py:163] Wall clock time: 9174896, 4 clients online, 0 clients offline
# (03-03) 20:44:06 INFO     [aggregator.py:308] Selected participants to run: [1, 2, 3, 4]:
# {1: {'computation': 1.8, 'communication': 339809.15625}, 2: {'computation': 1.8, 'communication': 339809.15625}, 3: {'computation': 1.8, 'communication': 339809.15625}, 4: {'computation': 1.8, 'communication': 339809.15625}}
# (03-03) 20:44:22 INFO     [aggregator.py:292] Wall clock: 9514707 s, Epoch: 29, Planned participants: 4, Succeed participants: 4, Training loss: 2.9094876071366818
# (03-03) 20:44:22 INFO     [client_manager.py:163] Wall clock time: 9514707, 4 clients online, 0 clients offline
# (03-03) 20:44:22 INFO     [aggregator.py:308] Selected participants to run: [1, 2, 3, 4]:
# {1: {'computation': 1.8, 'communication': 339809.15625}, 2: {'computation': 1.8, 'communication': 339809.15625}, 3: {'computation': 1.8, 'communication': 339809.15625}, 4: {'computation': 1.8, 'communication': 339809.15625}}
# (03-03) 20:44:39 INFO     [aggregator.py:292] Wall clock: 9854518 s, Epoch: 30, Planned participants: 4, Succeed participants: 4, Training loss: 2.87940881159009
# (03-03) 20:44:39 INFO     [client_manager.py:163] Wall clock time: 9854518, 4 clients online, 0 clients offline
# (03-03) 20:44:39 INFO     [aggregator.py:308] Selected participants to run: [1, 2, 3, 4]:
# {1: {'computation': 1.8, 'communication': 339809.15625}, 2: {'computation': 1.8, 'communication': 339809.15625}, 3: {'computation': 1.8, 'communication': 339809.15625}, 4: {'computation': 1.8, 'communication': 339809.15625}}
# (03-03) 20:44:43 INFO     [aggregator.py:376] FL Testing in epoch: 30, virtual_clock: 9854517.731250001, top_1: 27.53 %, top_5: 79.77 %, test loss: 1.9789, test len: 10000
# (03-03) 20:44:59 INFO     [aggregator.py:292] Wall clock: 10194329 s, Epoch: 31, Planned participants: 4, Succeed participants: 4, Training loss: 2.8505859588311915
# (03-03) 20:44:59 INFO     [client_manager.py:163] Wall clock time: 10194329, 4 clients online, 0 clients offline
# (03-03) 20:44:59 INFO     [aggregator.py:308] Selected participants to run: [1, 2, 3, 4]:
# {1: {'computation': 1.8, 'communication': 339809.15625}, 2: {'computation': 1.8, 'communication': 339809.15625}, 3: {'computation': 1.8, 'communication': 339809.15625}, 4: {'computation': 1.8, 'communication': 339809.15625}}
# (03-03) 20:45:16 INFO     [aggregator.py:292] Wall clock: 10534140 s, Epoch: 32, Planned participants: 4, Succeed participants: 4, Training loss: 2.8223454189659196
# (03-03) 20:45:16 INFO     [client_manager.py:163] Wall clock time: 10534140, 4 clients online, 0 clients offline
# (03-03) 20:45:16 INFO     [aggregator.py:308] Selected participants to run: [1, 2, 3, 4]:
# {1: {'computation': 1.8, 'communication': 339809.15625}, 2: {'computation': 1.8, 'communication': 339809.15625}, 3: {'computation': 1.8, 'communication': 339809.15625}, 4: {'computation': 1.8, 'communication': 339809.15625}}
# (03-03) 20:45:32 INFO     [aggregator.py:292] Wall clock: 10873951 s, Epoch: 33, Planned participants: 4, Succeed participants: 4, Training loss: 2.7968598494945858
# (03-03) 20:45:32 INFO     [client_manager.py:163] Wall clock time: 10873951, 4 clients online, 0 clients offline
# (03-03) 20:45:32 INFO     [aggregator.py:308] Selected participants to run: [1, 2, 3, 4]:
# {1: {'computation': 1.8, 'communication': 339809.15625}, 2: {'computation': 1.8, 'communication': 339809.15625}, 3: {'computation': 1.8, 'communication': 339809.15625}, 4: {'computation': 1.8, 'communication': 339809.15625}}
# (03-03) 20:45:49 INFO     [aggregator.py:292] Wall clock: 11213762 s, Epoch: 34, Planned participants: 4, Succeed participants: 4, Training loss: 2.772119233002268
# (03-03) 20:45:49 INFO     [client_manager.py:163] Wall clock time: 11213762, 4 clients online, 0 clients offline
# (03-03) 20:45:49 INFO     [aggregator.py:308] Selected participants to run: [1, 2, 3, 4]:
# {1: {'computation': 1.8, 'communication': 339809.15625}, 2: {'computation': 1.8, 'communication': 339809.15625}, 3: {'computation': 1.8, 'communication': 339809.15625}, 4: {'computation': 1.8, 'communication': 339809.15625}}
# (03-03) 20:46:05 INFO     [aggregator.py:292] Wall clock: 11553573 s, Epoch: 35, Planned participants: 4, Succeed participants: 4, Training loss: 2.747596070698961
# (03-03) 20:46:05 INFO     [client_manager.py:163] Wall clock time: 11553573, 4 clients online, 0 clients offline
# (03-03) 20:46:05 INFO     [aggregator.py:308] Selected participants to run: [1, 2, 3, 4]:
# {1: {'computation': 1.8, 'communication': 339809.15625}, 2: {'computation': 1.8, 'communication': 339809.15625}, 3: {'computation': 1.8, 'communication': 339809.15625}, 4: {'computation': 1.8, 'communication': 339809.15625}}
# (03-03) 20:46:09 INFO     [aggregator.py:376] FL Testing in epoch: 35, virtual_clock: 11553572.512500005, top_1: 28.87 %, top_5: 81.06 %, test loss: 1.9544, test len: 10000
# (03-03) 20:46:25 INFO     [aggregator.py:292] Wall clock: 11893383 s, Epoch: 36, Planned participants: 4, Succeed participants: 4, Training loss: 2.7257825400063616
# (03-03) 20:46:25 INFO     [client_manager.py:163] Wall clock time: 11893383, 4 clients online, 0 clients offline
# (03-03) 20:46:25 INFO     [aggregator.py:308] Selected participants to run: [1, 2, 3, 4]:
# {1: {'computation': 1.8, 'communication': 339809.15625}, 2: {'computation': 1.8, 'communication': 339809.15625}, 3: {'computation': 1.8, 'communication': 339809.15625}, 4: {'computation': 1.8, 'communication': 339809.15625}}
# (03-03) 20:46:42 INFO     [aggregator.py:292] Wall clock: 12233194 s, Epoch: 37, Planned participants: 4, Succeed participants: 4, Training loss: 2.705342978469112
# (03-03) 20:46:42 INFO     [client_manager.py:163] Wall clock time: 12233194, 4 clients online, 0 clients offline
# (03-03) 20:46:42 INFO     [aggregator.py:308] Selected participants to run: [1, 2, 3, 4]:
# {1: {'computation': 1.8, 'communication': 339809.15625}, 2: {'computation': 1.8, 'communication': 339809.15625}, 3: {'computation': 1.8, 'communication': 339809.15625}, 4: {'computation': 1.8, 'communication': 339809.15625}}
# (03-03) 20:46:58 INFO     [aggregator.py:292] Wall clock: 12573005 s, Epoch: 38, Planned participants: 4, Succeed participants: 4, Training loss: 2.6852963461624437
# (03-03) 20:46:58 INFO     [client_manager.py:163] Wall clock time: 12573005, 4 clients online, 0 clients offline
# (03-03) 20:46:58 INFO     [aggregator.py:308] Selected participants to run: [1, 2, 3, 4]:
# {1: {'computation': 1.8, 'communication': 339809.15625}, 2: {'computation': 1.8, 'communication': 339809.15625}, 3: {'computation': 1.8, 'communication': 339809.15625}, 4: {'computation': 1.8, 'communication': 339809.15625}}
# (03-03) 20:47:14 INFO     [aggregator.py:292] Wall clock: 12912816 s, Epoch: 39, Planned participants: 4, Succeed participants: 4, Training loss: 2.6666556048068033
# (03-03) 20:47:14 INFO     [client_manager.py:163] Wall clock time: 12912816, 4 clients online, 0 clients offline
# (03-03) 20:47:14 INFO     [aggregator.py:308] Selected participants to run: [1, 2, 3, 4]:
# {1: {'computation': 1.8, 'communication': 339809.15625}, 2: {'computation': 1.8, 'communication': 339809.15625}, 3: {'computation': 1.8, 'communication': 339809.15625}, 4: {'computation': 1.8, 'communication': 339809.15625}}
# (03-03) 20:47:31 INFO     [aggregator.py:292] Wall clock: 13252627 s, Epoch: 40, Planned participants: 4, Succeed participants: 4, Training loss: 2.6484631352462435
# (03-03) 20:47:31 INFO     [client_manager.py:163] Wall clock time: 13252627, 4 clients online, 0 clients offline
# (03-03) 20:47:31 INFO     [aggregator.py:308] Selected participants to run: [1, 2, 3, 4]:
# {1: {'computation': 1.8, 'communication': 339809.15625}, 2: {'computation': 1.8, 'communication': 339809.15625}, 3: {'computation': 1.8, 'communication': 339809.15625}, 4: {'computation': 1.8, 'communication': 339809.15625}}
# (03-03) 20:47:35 INFO     [aggregator.py:376] FL Testing in epoch: 40, virtual_clock: 13252627.293750009, top_1: 29.6 %, top_5: 80.98 %, test loss: 1.9337, test len: 10000
# (03-03) 20:47:51 INFO     [aggregator.py:292] Wall clock: 13592438 s, Epoch: 41, Planned participants: 4, Succeed participants: 4, Training loss: 2.6299189898416158
# (03-03) 20:47:51 INFO     [client_manager.py:163] Wall clock time: 13592438, 4 clients online, 0 clients offline
# (03-03) 20:47:51 INFO     [aggregator.py:308] Selected participants to run: [1, 2, 3, 4]:
# {1: {'computation': 1.8, 'communication': 339809.15625}, 2: {'computation': 1.8, 'communication': 339809.15625}, 3: {'computation': 1.8, 'communication': 339809.15625}, 4: {'computation': 1.8, 'communication': 339809.15625}}
# (03-03) 20:48:08 INFO     [aggregator.py:292] Wall clock: 13932249 s, Epoch: 42, Planned participants: 4, Succeed participants: 4, Training loss: 2.613580330472776
# (03-03) 20:48:08 INFO     [client_manager.py:163] Wall clock time: 13932249, 4 clients online, 0 clients offline
# (03-03) 20:48:08 INFO     [aggregator.py:308] Selected participants to run: [1, 2, 3, 4]:
# {1: {'computation': 1.8, 'communication': 339809.15625}, 2: {'computation': 1.8, 'communication': 339809.15625}, 3: {'computation': 1.8, 'communication': 339809.15625}, 4: {'computation': 1.8, 'communication': 339809.15625}}
# (03-03) 20:48:23 INFO     [aggregator.py:292] Wall clock: 14272060 s, Epoch: 43, Planned participants: 4, Succeed participants: 4, Training loss: 2.5973808666333236
# (03-03) 20:48:23 INFO     [client_manager.py:163] Wall clock time: 14272060, 4 clients online, 0 clients offline
# (03-03) 20:48:23 INFO     [aggregator.py:308] Selected participants to run: [1, 2, 3, 4]:
# {1: {'computation': 1.8, 'communication': 339809.15625}, 2: {'computation': 1.8, 'communication': 339809.15625}, 3: {'computation': 1.8, 'communication': 339809.15625}, 4: {'computation': 1.8, 'communication': 339809.15625}}
# (03-03) 20:48:40 INFO     [aggregator.py:292] Wall clock: 14611871 s, Epoch: 44, Planned participants: 4, Succeed participants: 4, Training loss: 2.581950190425079
# (03-03) 20:48:40 INFO     [client_manager.py:163] Wall clock time: 14611871, 4 clients online, 0 clients offline
# (03-03) 20:48:40 INFO     [aggregator.py:308] Selected participants to run: [1, 2, 3, 4]:
# {1: {'computation': 1.8, 'communication': 339809.15625}, 2: {'computation': 1.8, 'communication': 339809.15625}, 3: {'computation': 1.8, 'communication': 339809.15625}, 4: {'computation': 1.8, 'communication': 339809.15625}}
# (03-03) 20:48:56 INFO     [aggregator.py:292] Wall clock: 14951682 s, Epoch: 45, Planned participants: 4, Succeed participants: 4, Training loss: 2.5669840955698096
# (03-03) 20:48:56 INFO     [client_manager.py:163] Wall clock time: 14951682, 4 clients online, 0 clients offline
# (03-03) 20:48:56 INFO     [aggregator.py:308] Selected participants to run: [1, 2, 3, 4]:
# {1: {'computation': 1.8, 'communication': 339809.15625}, 2: {'computation': 1.8, 'communication': 339809.15625}, 3: {'computation': 1.8, 'communication': 339809.15625}, 4: {'computation': 1.8, 'communication': 339809.15625}}
# (03-03) 20:49:01 INFO     [aggregator.py:376] FL Testing in epoch: 45, virtual_clock: 14951682.075000012, top_1: 30.53 %, top_5: 83.11 %, test loss: 1.9210, test len: 10000
# (03-03) 20:49:16 INFO     [aggregator.py:292] Wall clock: 15291493 s, Epoch: 46, Planned participants: 4, Succeed participants: 4, Training loss: 2.5510245712038477
# (03-03) 20:49:16 INFO     [client_manager.py:163] Wall clock time: 15291493, 4 clients online, 0 clients offline
# (03-03) 20:49:16 INFO     [aggregator.py:308] Selected participants to run: [1, 2, 3, 4]:
# {1: {'computation': 1.8, 'communication': 339809.15625}, 2: {'computation': 1.8, 'communication': 339809.15625}, 3: {'computation': 1.8, 'communication': 339809.15625}, 4: {'computation': 1.8, 'communication': 339809.15625}}
# (03-03) 20:49:32 INFO     [aggregator.py:292] Wall clock: 15631304 s, Epoch: 47, Planned participants: 4, Succeed participants: 4, Training loss: 2.5370901284159957
# (03-03) 20:49:32 INFO     [client_manager.py:163] Wall clock time: 15631304, 4 clients online, 0 clients offline
# (03-03) 20:49:32 INFO     [aggregator.py:308] Selected participants to run: [1, 2, 3, 4]:
# {1: {'computation': 1.8, 'communication': 339809.15625}, 2: {'computation': 1.8, 'communication': 339809.15625}, 3: {'computation': 1.8, 'communication': 339809.15625}, 4: {'computation': 1.8, 'communication': 339809.15625}}
# (03-03) 20:49:48 INFO     [aggregator.py:292] Wall clock: 15971115 s, Epoch: 48, Planned participants: 4, Succeed participants: 4, Training loss: 2.52342436993204
# (03-03) 20:49:48 INFO     [client_manager.py:163] Wall clock time: 15971115, 4 clients online, 0 clients offline
# (03-03) 20:49:48 INFO     [aggregator.py:308] Selected participants to run: [1, 2, 3, 4]:
# {1: {'computation': 1.8, 'communication': 339809.15625}, 2: {'computation': 1.8, 'communication': 339809.15625}, 3: {'computation': 1.8, 'communication': 339809.15625}, 4: {'computation': 1.8, 'communication': 339809.15625}}
# (03-03) 20:50:05 INFO     [aggregator.py:292] Wall clock: 16310926 s, Epoch: 49, Planned participants: 4, Succeed participants: 4, Training loss: 2.510519155341659
# (03-03) 20:50:05 INFO     [client_manager.py:163] Wall clock time: 16310926, 4 clients online, 0 clients offline
# (03-03) 20:50:05 INFO     [aggregator.py:308] Selected participants to run: [1, 2, 3, 4]:
# {1: {'computation': 1.8, 'communication': 339809.15625}, 2: {'computation': 1.8, 'communication': 339809.15625}, 3: {'computation': 1.8, 'communication': 339809.15625}, 4: {'computation': 1.8, 'communication': 339809.15625}}
# (03-03) 20:50:21 INFO     [aggregator.py:292] Wall clock: 16650737 s, Epoch: 50, Planned participants: 4, Succeed participants: 4, Training loss: 2.4984337478283076
# (03-03) 20:50:21 INFO     [client_manager.py:163] Wall clock time: 16650737, 4 clients online, 0 clients offline
# (03-03) 20:50:21 INFO     [aggregator.py:308] Selected participants to run: [1, 2, 3, 4]:
# {1: {'computation': 1.8, 'communication': 339809.15625}, 2: {'computation': 1.8, 'communication': 339809.15625}, 3: {'computation': 1.8, 'communication': 339809.15625}, 4: {'computation': 1.8, 'communication': 339809.15625}}
# (03-03) 20:50:21 INFO     [aggregator.py:503] Terminating the aggregator ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_148801/2984055253.py in <module>
#       5 from FedScale.core.fl_client_libs import args
#       6 Demo_Aggregator = Aggregator(args)
# ----> 7 Demo_Aggregator.run()
#
# ~/FedScale/core/aggregator.py in run(self)
#     219         self.model_update_size = sys.getsizeof(pickle.dumps(self.model))/1024.0*8. # kbits
#     220         self.client_profiles = self.load_client_profile(file_path=self.args.device_conf_file)
# --> 221         self.event_monitor()
#     222
#     223
#
# ~/FedScale/core/aggregator.py in event_monitor(self)
#     481                         _ = self.executors.get_stub(executorId).Stop.future(job_api_pb2.StopRequest())
#     482
# --> 483                     self.stop()
#     484                     break
#     485
#
# ~/FedScale/core/aggregator.py in stop(self)
#     503         logging.info(f"Terminating the aggregator ...")
#     504         time.sleep(5)
# --> 505         self.control_manager.shutdown()
#     506
#     507 if __name__ == "__main__":
#
# AttributeError: 'Aggregator' object has no attribute 'control_manager'

# %%
# !tensorboard --logdir=./logs/demo_job --port=6006 --bind_all
# Out:
# /users/Yinwei
# TensorFlow installation not found - running with reduced feature set.
#
# NOTE: Using experimental fast data loading logic. To disable, pass
#     "--load_fast=false" and report issues on GitHub. More details:
#     https://github.com/tensorflow/tensorboard/issues/4784
#
# TensorBoard 2.8.0 at http://clnode219.clemson.cloudlab.us:6006/ (Press CTRL+C to quit)
# ^C
